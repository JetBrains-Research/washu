# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

from IPython.display import display
import pandas as pd
import numpy as np
from statistics import stdev

df = pd.read_csv('/mnt/stripe/bio/experiments/figures/Peak Calling Summary - aging.tsv', sep='\t')
df = df.loc[df['Status'] != 'Failed']
display(df.head(1))

result = pd.DataFrame(columns=['mark', 'tool', 'procedure', 
                               'peaks_avg', 'peaks_stdev', 
                               'sumlen_avg', 'sumlen_stdev',
                               'len_avg', 'len_stdev',
                               'frip_avg', 'frip_stdev'])
for m in set(df['modification']):
    dfm = df.loc[df['modification'] == m]
    for t in set(dfm['tool']):
        dfmt = dfm.loc[dfm['tool'] == t]
        for p in ['tuned']: #set(dfmt['procedure']):
            dfmtp = dfmt.loc[dfmt['procedure'] == p]
            print(m, t, p)
#             display(dfmtp)
            peaks_avg = int(np.mean(dfmtp['peaks']))
            peaks_stdev = int(stdev(dfmtp['peaks']))
            sumlen_avg = int(np.mean(dfmtp['length'] / 10e6))
            sumlen_stdev = int(stdev(dfmtp['length'] / 10e6))
            l = dfmtp['length'] / dfmtp['peaks']
            l.loc[~np.isfinite(l)] = 0.0
            len_avg = int(np.mean(l))
            len_stdev = int(stdev(l))
            frip_avg = int(np.mean(dfmtp['FRiP']))
            frip_stdev = int(stdev(dfmtp['FRiP']))
            result.loc[len(result)] = (m, t, p, 
                                       peaks_avg, peaks_stdev, 
                                       sumlen_avg, sumlen_stdev,
                                      len_avg, len_stdev, 
                                      frip_avg, frip_stdev)

display(result)
print(list(result.columns))
# Out:
#   donor modification   tool  peaks    length     FRiP procedure  \
# 0   OD1      H3K27ac  MACS2  21843  25197959  16.0923   default
#
#                           params  \
# 0  --broad --broad-cutoff 1.0E-4
#
#                                                 file      tags  duplicates  \
# 0  /mnt/stripe/bio/experiments/aging/peak_calling...  31047948        0.14
#
#   Status
# 0    NaN
# H3K4me3 ZINBRA tuned
# H3K4me3 MACS2 tuned
# H3K36me3 ZINBRA tuned
# H3K36me3 SICER tuned
# H3K36me3 MACS2 tuned
# H3K4me1 ZINBRA tuned
# H3K4me1 MACS2 tuned
# H3K27me3 ZINBRA tuned
# H3K27me3 SICER tuned
# H3K27me3 MACS2 tuned
# H3K27ac ZINBRA tuned
# H3K27ac MACS2 tuned
#         mark    tool procedure  peaks_avg  peaks_stdev  sumlen_avg  \
# 0    H3K4me3  ZINBRA     tuned    15682.0       1741.0         3.0
# 1    H3K4me3   MACS2     tuned    13885.0       3897.0         1.0
# 2   H3K36me3  ZINBRA     tuned    10712.0       2148.0        26.0
# 3   H3K36me3   SICER     tuned    19917.0       5228.0        41.0
# 4   H3K36me3   MACS2     tuned    50617.0      15903.0        10.0
# 5    H3K4me1  ZINBRA     tuned    63876.0       7679.0        15.0
# 6    H3K4me1   MACS2     tuned    80796.0      20846.0        10.0
# 7   H3K27me3  ZINBRA     tuned     6710.0        600.0         4.0
# 8   H3K27me3   SICER     tuned    17558.0       7587.0        10.0
# 9   H3K27me3   MACS2     tuned    10967.0       2855.0         1.0
# 10   H3K27ac  ZINBRA     tuned    23385.0       3709.0         3.0
# 11   H3K27ac   MACS2     tuned    24074.0       3811.0         2.0
#
#     sumlen_stdev  len_avg  len_stdev  frip_avg  frip_stdev
# 0            1.0   1892.0      547.0       8.0         2.0
# 1            0.0    913.0      206.0       6.0         3.0
# 2            5.0  25440.0     5008.0      41.0        11.0
# 3            6.0  22231.0     7527.0      54.0        11.0
# 4            6.0   1936.0      808.0      26.0        14.0
# 5            1.0   2521.0      459.0      38.0        11.0
# 6            3.0   1253.0      302.0      33.0        13.0
# 7            0.0   6753.0      778.0      12.0         3.0
# 8            4.0   6593.0     1622.0      19.0         8.0
# 9            0.0   1694.0      517.0       8.0         4.0
# 10           0.0   1426.0      267.0      23.0        11.0
# 11           0.0   1217.0       96.0      22.0        12.0
# ['mark', 'tool', 'procedure', 'peaks_avg', 'peaks_stdev', 'sumlen_avg', 'sumlen_stdev', 'len_avg', 'len_stdev', 'frip_avg', 'frip_stdev']
