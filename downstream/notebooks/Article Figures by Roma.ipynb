# %% [markdown]
# ** For Article: **
# 1. All donors vs all donors (all marks) peaks **overlap**(inclusion) / correlation / jaccard metrics.
# 2. **Avg depth of sequencing**: barplot with st dev&dots.
# 3. Heatmap tuned zibra vs chromhmm + supplemeratry (all tools vs chromhmm)
#
# ** Misc: **
# * Lib Depth by Chr

# %%
import os, sys
import re
from collections import OrderedDict, Counter
from itertools import chain

from pathlib import Path
import pandas as pd

# %%
from collections import Counter

# %%
# Ensure project configured
! echo $WASHU_ROOT
# Out:
# /mnt/stripe/washu

# %%
# whether to clear cached_results or not:
clear_cache = False

# %%
! echo $PYTHONPATH
# Out:
# /mnt/stripe/washu:/mnt/stripe/washu:

# %%
import downstream.bed_metrics as bm
import downstream.loci_of_interest as loi

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
from IPython.display import display

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
def color_annotator_hist(label):
    chunks = list(label.split("_"))
    hist, _donor, _tool = chunks
    color = {'H3K4me1':'lightblue', 'H3K4me3':'red', 'H3K27ac':'black',
             'H3K27me3':'green', 'H3K36me3':'lightgray'}[hist]

    return (("Histone", color),)

# %%
def build_fig8(hist_mods, df_path, jaccard,
               tools_label, df_failed_tracks, *,
               row_cluster=False,
               plot_path = None):
    print("Tools:")
    print(*["  {}:{}".format(k, v) for k,v in hist_mods.items()], sep="\n")

    # -----------------------------------
    # Collect tracks:
    hist_2_tracks = {}
    
    for f in hfolders:
        match = re.match(".*/(H[^/]*)/([^/]*).*", f, flags=re.IGNORECASE)
        assert match
        hist = match.group(1)
        tool = match.group(2)

        if hist_mods.get(hist, None) != tool:
            continue

        tracks = loi.collect_peaks_in_folder(Path(f))
        hist_2_tracks[hist] = tracks

    print("\nAll Tracks:")
    for h in hist_mods:
        tracks = hist_2_tracks[h]
        assert tracks, "No tracks for {}".format(h)
        print("  {} [{}], {}..{}".format(
            h, len(tracks), Path(tracks[0]).name, Path(tracks[-1]).name)
        )
    
    all_donors_paths = list(chain(*(hist_2_tracks[h] for h in hist_mods)))
    print("\nAll donors paths: (first 5) or {}".format(len(all_donors_paths)),
          *all_donors_paths[0:5], sep="\n    ")

    # -----------------------------------
    print("\nMetrics table:")
    print(df_path)
    df = bm.load_or_build_metrics_table(all_donors_paths, all_donors_paths, df_path,
                                        jaccard=jaccard,
                                        threads=30)
    
    # ------------------------------------
    def passed_mask(labels, df_failed_tracks):
        if labels is None:
            return [True for l in labels]
        
        passed_donors_for_hist = {}
        mask = []
        for label in labels:
            match = re.match(".*_(H[A-Z0-9]*)[_-].*", label, flags=re.IGNORECASE)
            assert match, "Unsupported donor label format: " + label
            hist = match.group(1)
            if hist not in passed_donors_for_hist:
                    passed_donors_for_hist[hist] = set(df_failed_tracks.index[df_failed_tracks[hist] == 0])
            passed_donors = passed_donors_for_hist[hist]
            mask.append(bm.label_converter_donor_and_tool(label).split("_")[0] in passed_donors)
        return mask
        
    print()
    if df_failed_tracks is not None:
        print("Use only passed (not failed) tracks")

        col_mask = passed_mask(df.columns, df_failed_tracks)
        row_mask = passed_mask(df.index, df_failed_tracks)
        
        for c in (c for c in df_failed_tracks.columns if c.startswith("H")):
            print("  {}: {} or {}".format(
                str(c), sum(df_failed_tracks[c] == 0), sum(df_failed_tracks[c] != -1)
            ))
            
        origin_shape = df.shape
        df = df.loc[row_mask, col_mask]
        print("Passed tracks table: {0[0]}x{0[1]} of {1[0]}x{1[1]}".format(
            df.shape, origin_shape
        ))        
    else:
        print("Use all donors tracks")

    print("Columns: (first 5)", *df.columns.tolist()[0:5], sep="\n    ")
    
    def short_label(labels):
        res = []
        for label in labels:
            match = re.match(".*_(H[A-Z0-9]*)[_-].*", label, flags=re.IGNORECASE)
            assert match, "Unsupported donor label format: " + label
            hist = match.group(1)
            res.append(hist + "_" + bm.label_converter_donor_and_tool(label))        
        return res
    
    df.index = short_label(df.index)
    df.columns = short_label(df.columns)

    # -----------------------------------
    # Plot:
    annotator = color_annotator_hist
    # annotator = bm.color_annotator_chain(color_annotator_hist, bm.color_annotator_age)
    metrics = "Jaccard" if jaccard else "Overlap"
    g = bm.plot_metric_heatmap(metrics, #IM: {}".format(df_path.name), 
                               df,
                               save_to=plot_path,
                               row_cluster=row_cluster, 
                               col_cluster=False,
                               row_color_annotator=annotator,
                               col_color_annotator=annotator,
                               row_colors_ratio=0.025, col_colors_ratio=0.025,
                               # todo y/o
                               figsize=(10, 10), 
                               show_or_save_plot=False)

    # Replace tics: Use just histone modifications for donors groups:
    # we expect same ticks at OX, OY, it just slightly simplifies further impl.
    assert df.index.tolist() == df.columns.tolist()
    
    hist_donors_cnt = Counter()
    for short_label in df.columns:
        hist = short_label.split("_")[0]
        hist_donors_cnt[hist] += 1
    hist_donors_counts = [hist_donors_cnt[h] for h in hist_mods]
    
    ticks = [sum(hist_donors_counts[0:k]) + hist_donors_counts[k]/2 for k in range(len(hist_donors_counts))]
    g.ax_heatmap.set_xticks(ticks)
    g.ax_heatmap.set_xticklabels(hist_mods.keys(), rotation="horizontal", horizontalalignment = 'center')
    g.ax_heatmap.set_yticks(ticks)
    g.ax_heatmap.set_yticklabels(hist_mods.keys(), rotation="vertical", verticalalignment = 'center')

    plt.setp(g.ax_heatmap.get_yticklabels(), rotation=90)
    
    # Turn off annotations
    g.ax_col_colors.set_yticks([])
    g.ax_row_colors.set_xticks([])

    g.ax_col_colors.set_title("{} {}".format(metrics, tools_label))
    
    # Turn off Y lables:
    if row_cluster == True:
        g.ax_heatmap.set_yticks([])
    
    bm.save_plot(plot_path)

# %%
def color_annotator_hist(label):
    chunks = list(label.split("_"))
    hist, _donor, _tool = chunks

    # pastel
    # color = {'H3K27ac':'tomato', 'H3K27me3':'mediumorchid', 'H3K36me3':'cornflowerblue', 
    #          'H3K4me1':'orange', 'H3K4me3':'mediumseagreen'}[hist]
    
    color = {'H3K27ac':'red', 'H3K27me3':'darkorchid', 'H3K36me3':'blue', 
             'H3K4me1':'orange', 'H3K4me3':'green'}[hist]

    return (("Histone", color),)

# %%
root_path = Path("/mnt/stripe/bio/experiments/configs/benchmark/benchmark")

# %% [markdown]
# # Figures

# %% [markdown]
# ## All Donors & All Marks  Overlap  / Jaccard Metrics

# %%
# TODO: linewidths=0.75

# %%
hfolders = !find $root_path -maxdepth 2 -type d -wholename $root_path"/H*/*"
# hfolders = !find $root_path -maxdepth 2 -type d

print(*hfolders, sep="\n")
# Out:
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27ac/macs_broad
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27ac/macs_narrow
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27ac/sicer
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27ac/zinbra_replicated
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27ac/zinbra_split
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27ac/zinbra
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27ac/zinbra_split_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27ac/zinbra_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27me3/macs_broad
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27me3/macs_narrow
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27me3/sicer
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27me3/zinbra_replicated
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27me3/zinbra_joint
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27me3/zinbra_split
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27me3/zinbra
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27me3/zinbra_split_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K27me3/zinbra_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_narrow
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra_replicated
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra_split
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra_split_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/macs_broad
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/macs_narrow
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_replicated
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_split
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_split_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_fragment
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_fragment_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K36me3/macs_broad
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K36me3/macs_narrow
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K36me3/sicer
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K36me3/zinbra_replicated
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K36me3/zinbra_split
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K36me3/zinbra
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K36me3/zinbra_split_noinput
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K36me3/zinbra_noinput

# %%
failed_tracks = "/mnt/stripe/bio/experiments/aging/Y20O20.failed_tracks.csv"
df_failed_tracks = pd.read_csv(failed_tracks, sep="\t", comment="#", index_col=0)
df_failed_tracks.head(5)
# Out:
#        H3K27ac  H3K27me3  H3K36me3  H3K4me1  H3K4me3  Input  methylation  \
# donor
# OD1          0         0         0       -1        0     -1            0
# OD10         0         0         0        0        0     -1            0
# OD11         0         0         0        0        0     -1            0
# OD12         0         0         0        0        0     -1            0
# OD13         0         0         0        0        0     -1            0
#
#        mirna  transcription
# donor
# OD1        0              0
# OD10       0              0
# OD11      -1             -1
# OD12      -1             -1
# OD13      -1             -1

# %% [markdown]
# ### Jaccard

# %% [markdown]
# #### Extra: Zinbra

# %%
path, tool, title = root_path / "fig10_wo_failed_ji_zinbra.csv", "zinbra", "ZIBRA"
if clear_cache:
    ! rm $path
build_fig8(OrderedDict([('H3K4me1', tool),
                        ('H3K4me3', tool),
                        ('H3K27ac', tool),
                        ('H3K27me3', tool),
                        ('H3K36me3', tool)]), 
           path, True, title, df_failed_tracks)

# %% [markdown]
# #### Extra: Zinbra No Input

# %%
path, tool, title = root_path / "fig10_wo_failed_ji_zinbra_noinput.csv", "zinbra_noinput", "ZIBRA w/o Input"
if clear_cache:
    ! rm $path
build_fig8(OrderedDict([#('H3K4me1', tool),
                        ('H3K4me3', tool),
                        #('H3K27ac', tool),
                        #('H3K27me3', tool),
                        ('H3K36me3', tool)]), 
           path, True, title, df_failed_tracks)
# Out:
# Tools:
#   H3K4me3:zinbra_noinput
#   H3K36me3:zinbra_noinput
#
# All Tracks:
#   H3K4me3 [40], OD_OD1_H3K4me3_1.0E-4_10_peaks.bed..YD_YD21_H3K4me3_1.0E-6_10_peaks.bed
#   H3K36me3 [39], OD_OD1_H3K36me3_1.0E-10_80_peaks.bed..YD_YD21_H3K36me3_1.0E-8_60_peaks.bed
#
# All donors paths: (first 5) or 79
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD1_H3K4me3_1.0E-4_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD2_H3K4me3_1.0E-4_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD3_H3K4me3_1.0E-8_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD4_H3K4me3_1.0E-8_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD5_H3K4me3_1.0E-6_10_peaks.bed
#
# Metrics table:
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_ji_zinbra_noinput.csv
# [Skipped]: Already exists /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_ji_zinbra_noinput.csv
#
# Use only passed (not failed) tracks
#   H3K27ac: 38 or 40
#   H3K27me3: 32 or 40
#   H3K36me3: 32 or 39
#   H3K4me1: 32 or 32
#   H3K4me3: 33 or 40
# Passed tracks table: 65x65 of 79x79
# Columns: (first 5)
#     OD_OD1_H3K4me3_1.0E-4_10_peaks.bed
#     OD_OD2_H3K4me3_1.0E-4_10_peaks.bed
#     OD_OD3_H3K4me3_1.0E-8_10_peaks.bed
#     OD_OD4_H3K4me3_1.0E-8_10_peaks.bed
#     OD_OD5_H3K4me3_1.0E-6_10_peaks.bed

# %% [markdown]
# #### Extra: Zinra Split

# %%
path, tool, title = root_path / "fig10_wo_failed_ji_zinbra_split.csv", "zinbra_split", "ZIBRA"
if clear_cache:
    ! rm $path
build_fig8(OrderedDict([('H3K4me1', tool),
                        ('H3K4me3', tool),
                        ('H3K27ac', tool),
                        ('H3K27me3', tool),
                        ('H3K36me3', tool)]), 
           path, True, title, df_failed_tracks)
# Out:
# Tools:
#   H3K4me1:zinbra_split
#   H3K4me3:zinbra_split
#   H3K27ac:zinbra_split
#   H3K27me3:zinbra_split
#   H3K36me3:zinbra_split
#
# All Tracks:
#   H3K4me1 [32], OD_OD4_H3K4me1_1.0E-6_10_peaks.bed..YD_YD20_H3K4me1_1.0E-10_5_peaks.bed
#   H3K4me3 [40], OD_OD1_H3K4me3_0.01_10_peaks.bed..YD_YD21_H3K4me3_1.0E-4_10_peaks.bed
#   H3K27ac [40], OD_OD1_H3K27ac_1.0E-4_2_peaks.bed..YD_YD21_H3K27ac_1.0E-10_5_peaks.bed
#   H3K27me3 [40], OD_OD1_H3K27me3_1.0E-8_80_peaks.bed..YD_YD21_H3K27me3_1.0E-10_80_peaks.bed
#   H3K36me3 [39], OD_OD1_H3K36me3_1.0E-8_40_peaks.bed..YD_YD21_H3K36me3_1.0E-6_40_peaks.bed
#
# All donors paths: (first 5) or 191
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra_split/OD_OD4_H3K4me1_1.0E-6_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra_split/OD_OD5_H3K4me1_1.0E-4_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra_split/OD_OD6_H3K4me1_1.0E-6_5_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra_split/OD_OD7_H3K4me1_1.0E-4_5_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra_split/OD_OD8_H3K4me1_1.0E-8_10_peaks.bed
#
# Metrics table:
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_ji_zinbra_split.csv
# [Skipped]: Already exists /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_ji_zinbra_split.csv
#
# Use only passed (not failed) tracks
#   H3K27ac: 38 or 40
#   H3K27me3: 32 or 40
#   H3K36me3: 32 or 39
#   H3K4me1: 32 or 32
#   H3K4me3: 33 or 40
# Passed tracks table: 167x167 of 191x191
# Columns: (first 5)
#     OD_OD4_H3K4me1_1.0E-6_10_peaks.bed
#     OD_OD5_H3K4me1_1.0E-4_10_peaks.bed
#     OD_OD6_H3K4me1_1.0E-6_5_peaks.bed
#     OD_OD7_H3K4me1_1.0E-4_5_peaks.bed
#     OD_OD8_H3K4me1_1.0E-8_10_peaks.bed

# %% [markdown]
# #### Extra: Golden

# %%
path = root_path / "fig10_wo_failed_ji_golden.csv"
if clear_cache:
    ! rm $path
build_fig8(OrderedDict([('H3K4me1', "macs_broad"),
                        ('H3K4me3', "macs_broad"),
                        ('H3K27ac', "macs_broad"),
                        ('H3K27me3', "sicer"),
                        ('H3K36me3', "sicer")]), 
           path, True, "MACS2 (broad) and SICER", df_failed_tracks)
# Out:
# Tools:
#   H3K4me1:macs_broad
#   H3K4me3:macs_broad
#   H3K27ac:macs_broad
#   H3K27me3:sicer
#   H3K36me3:sicer
#
# All Tracks:
#   H3K4me1 [32], OD_OD4_H3K4me1_broad0.01_peaks.broadPeak..YD_YD20_H3K4me1_broad1.0E-6_peaks.broadPeak
#   H3K4me3 [40], OD_OD1_H3K4me3_broad0.01_peaks.broadPeak..YD_YD21_H3K4me3_broad0.01_peaks.broadPeak
#   H3K27ac [40], OD_OD1_H3K27ac_broad1.0E-4_peaks.broadPeak..YD_YD21_H3K27ac_broad1.0E-6_peaks.broadPeak
#   H3K27me3 [40], OD_OD1_H3K27me3-W200-G200-FDR1.0E-8-island.bed..YD_YD21_H3K27me3-W200-G600-FDR1.0E-8-island.bed
#   H3K36me3 [39], OD_OD1_H3K36me3-W200-G600-FDR1.0E-8-island.bed..YD_YD21_H3K36me3-W200-G1200-FDR1.0E-8-island.bed
#
# All donors paths: (first 5) or 191
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD4_H3K4me1_broad0.01_peaks.broadPeak
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD5_H3K4me1_broad0.01_peaks.broadPeak
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD6_H3K4me1_broad0.01_peaks.broadPeak
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD7_H3K4me1_broad0.01_peaks.broadPeak
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD8_H3K4me1_broad1.0E-4_peaks.broadPeak
#
# Metrics table:
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_ji_golden.csv
# [Skipped]: Already exists /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_ji_golden.csv
#
# Use only passed (not failed) tracks
#   H3K27ac: 38 or 40
#   H3K27me3: 32 or 40
#   H3K36me3: 32 or 39
#   H3K4me1: 32 or 32
#   H3K4me3: 33 or 40
# Passed tracks table: 167x167 of 191x191
# Columns: (first 5)
#     OD_OD4_H3K4me1_broad0.01_peaks.broadPeak
#     OD_OD5_H3K4me1_broad0.01_peaks.broadPeak
#     OD_OD6_H3K4me1_broad0.01_peaks.broadPeak
#     OD_OD7_H3K4me1_broad0.01_peaks.broadPeak
#     OD_OD8_H3K4me1_broad1.0E-4_peaks.broadPeak

# %% [markdown]
# ### Overlap ZINBRA tuned without outliers

# %% [markdown]
# #### Main: Zinbra

# %%
path, tool, title = root_path / "fig10_wo_failed_im_zinbra.csv", "zinbra", "ZINBRA"
if clear_cache:
    ! rm $path
build_fig8(OrderedDict([('H3K4me1', tool),
                        ('H3K4me3', tool),
                        ('H3K27ac', tool),
                        ('H3K27me3', tool),
                        ('H3K36me3', tool)]), 
           path, False, title, df_failed_tracks)

# save to PDF:
from matplotlib.backends.backend_pdf import PdfPages
with PdfPages(str(root_path / "fig1_panel_10.pdf")) as pdf:
    build_fig8(OrderedDict([('H3K4me1', tool),
                            ('H3K4me3', tool),
                            ('H3K27ac', tool),
                            ('H3K27me3', tool),
                            ('H3K36me3', tool)]), 
               path, False, title, df_failed_tracks,
           plot_path=pdf)
# Out:
# Tools:
#   H3K4me1:zinbra
#   H3K4me3:zinbra
#   H3K27ac:zinbra
#   H3K27me3:zinbra
#   H3K36me3:zinbra
#
# All Tracks:
#   H3K4me1 [32], OD_OD4_H3K4me1_1.0E-6_10_peaks.bed..YD_YD20_H3K4me1_1.0E-8_5_peaks.bed
#   H3K4me3 [40], OD_OD1_H3K4me3_0.01_5_peaks.bed..YD_YD21_H3K4me3_1.0E-4_5_peaks.bed
#   H3K27ac [40], OD_OD1_H3K27ac_1.0E-4_2_peaks.bed..YD_YD21_H3K27ac_1.0E-10_5_peaks.bed
#   H3K27me3 [40], OD_OD1_H3K27me3_1.0E-8_80_peaks.bed..YD_YD21_H3K27me3_1.0E-10_80_peaks.bed
#   H3K36me3 [39], OD_OD1_H3K36me3_1.0E-8_60_peaks.bed..YD_YD21_H3K36me3_1.0E-8_60_peaks.bed
#
# All donors paths: (first 5) or 191
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD4_H3K4me1_1.0E-6_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD5_H3K4me1_1.0E-4_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD6_H3K4me1_1.0E-6_5_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD7_H3K4me1_1.0E-4_5_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD8_H3K4me1_1.0E-8_10_peaks.bed
#
# Metrics table:
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig10_wo_failed_im_zinbra.csv
# Calculating metrics:  /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig10_wo_failed_im_zinbra.csv
#   [Saved] /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig10_wo_failed_im_zinbra.csv
#
# Use only passed (not failed) tracks
#   H3K27ac: 38 or 40
#   H3K27me3: 32 or 40
#   H3K36me3: 32 or 39
#   H3K4me1: 32 or 32
#   H3K4me3: 33 or 40
# Passed tracks table: 167x167 of 191x191
# Columns: (first 5)
#     OD_OD4_H3K4me1_1.0E-6_10_peaks.bed
#     OD_OD5_H3K4me1_1.0E-4_10_peaks.bed
#     OD_OD6_H3K4me1_1.0E-6_5_peaks.bed
#     OD_OD7_H3K4me1_1.0E-4_5_peaks.bed
#     OD_OD8_H3K4me1_1.0E-8_10_peaks.bed
# Tools:
#   H3K4me1:zinbra
#   H3K4me3:zinbra
#   H3K27ac:zinbra
#   H3K27me3:zinbra
#   H3K36me3:zinbra
#
# All Tracks:
#   H3K4me1 [32], OD_OD4_H3K4me1_1.0E-6_10_peaks.bed..YD_YD20_H3K4me1_1.0E-8_5_peaks.bed
#   H3K4me3 [40], OD_OD1_H3K4me3_0.01_5_peaks.bed..YD_YD21_H3K4me3_1.0E-4_5_peaks.bed
#   H3K27ac [40], OD_OD1_H3K27ac_1.0E-4_2_peaks.bed..YD_YD21_H3K27ac_1.0E-10_5_peaks.bed
#   H3K27me3 [40], OD_OD1_H3K27me3_1.0E-8_80_peaks.bed..YD_YD21_H3K27me3_1.0E-10_80_peaks.bed
#   H3K36me3 [39], OD_OD1_H3K36me3_1.0E-8_60_peaks.bed..YD_YD21_H3K36me3_1.0E-8_60_peaks.bed
#
# All donors paths: (first 5) or 191
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD4_H3K4me1_1.0E-6_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD5_H3K4me1_1.0E-4_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD6_H3K4me1_1.0E-6_5_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD7_H3K4me1_1.0E-4_5_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/zinbra/OD_OD8_H3K4me1_1.0E-8_10_peaks.bed
#
# Metrics table:
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig10_wo_failed_im_zinbra.csv
# [Skipped]: Already exists /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig10_wo_failed_im_zinbra.csv
#
# Use only passed (not failed) tracks
#   H3K27ac: 38 or 40
#   H3K27me3: 32 or 40
#   H3K36me3: 32 or 39
#   H3K4me1: 32 or 32
#   H3K4me3: 33 or 40
# Passed tracks table: 167x167 of 191x191
# Columns: (first 5)
#     OD_OD4_H3K4me1_1.0E-6_10_peaks.bed
#     OD_OD5_H3K4me1_1.0E-4_10_peaks.bed
#     OD_OD6_H3K4me1_1.0E-6_5_peaks.bed
#     OD_OD7_H3K4me1_1.0E-4_5_peaks.bed
#     OD_OD8_H3K4me1_1.0E-8_10_peaks.bed

# %% [markdown]
# #### Extra: Zinbra No Input

# %%
path, tool, title = root_path / "fig10_wo_failed_im_zinbra_noinput.csv", "zinbra_noinput", "ZIBRA w/o Input"
if clear_cache:
    ! rm $path
build_fig8(OrderedDict([#('H3K4me1', tool),
                        ('H3K4me3', tool),
                        #('H3K27ac', tool),
                        #('H3K27me3', tool),
                        ('H3K36me3', tool)]), 
           path, False, title, df_failed_tracks)
# Out:
# Tools:
#   H3K4me3:zinbra_noinput
#   H3K36me3:zinbra_noinput
#
# All Tracks:
#   H3K4me3 [40], OD_OD1_H3K4me3_1.0E-4_10_peaks.bed..YD_YD21_H3K4me3_1.0E-6_10_peaks.bed
#   H3K36me3 [39], OD_OD1_H3K36me3_1.0E-10_80_peaks.bed..YD_YD21_H3K36me3_1.0E-8_60_peaks.bed
#
# All donors paths: (first 5) or 79
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD1_H3K4me3_1.0E-4_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD2_H3K4me3_1.0E-4_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD3_H3K4me3_1.0E-8_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD4_H3K4me3_1.0E-8_10_peaks.bed
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me3/zinbra_noinput/OD_OD5_H3K4me3_1.0E-6_10_peaks.bed
#
# Metrics table:
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_im_zinbra_noinput.csv
# [Skipped]: Already exists /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_im_zinbra_noinput.csv
#
# Use only passed (not failed) tracks
#   H3K27ac: 38 or 40
#   H3K27me3: 32 or 40
#   H3K36me3: 32 or 39
#   H3K4me1: 32 or 32
#   H3K4me3: 33 or 40
# Passed tracks table: 65x65 of 79x79
# Columns: (first 5)
#     OD_OD1_H3K4me3_1.0E-4_10_peaks.bed
#     OD_OD2_H3K4me3_1.0E-4_10_peaks.bed
#     OD_OD3_H3K4me3_1.0E-8_10_peaks.bed
#     OD_OD4_H3K4me3_1.0E-8_10_peaks.bed
#     OD_OD5_H3K4me3_1.0E-6_10_peaks.bed

# %% [markdown]
# #### Extra: Zinbra Split

# %%
path, tool, title = root_path / "fig10_wo_failed_im_zinbra_split.csv", "zinbra_split", "ZIBRA"
if clear_cache:
    ! rm $path
build_fig8(OrderedDict([('H3K4me1', tool),
                        ('H3K4me3', tool),
                        ('H3K27ac', tool),
                        ('H3K27me3', tool),
                        ('H3K36me3', tool)]), 
           path, False, title, df_failed_tracks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2bf47ed67b88> in <module>()
#       2 if clear_cache:
#       3     get_ipython().system(' rm $path')
# ----> 4 build_fig8(OrderedDict([('H3K4me1', tool),
#       5                         ('H3K4me3', tool),
#       6                         ('H3K27ac', tool),
#
# NameError: name 'build_fig8' is not defined

# %% [markdown]
# #### Extra: Golden

# %%
path = root_path / "fig10_wo_failed_im_golden.csv"
if clear_cache:
    ! rm $path
build_fig8(OrderedDict([('H3K4me1', "macs_broad"),
                        ('H3K4me3', "macs_broad"),
                        ('H3K27ac', "macs_broad"),
                        ('H3K27me3', "sicer"),
                        ('H3K36me3', "sicer")]), 
           path, False, "MACS2 (broad) and SICER", df_failed_tracks)
# Out:
# Tools:
#   H3K4me1:macs_broad
#   H3K4me3:macs_broad
#   H3K27ac:macs_broad
#   H3K27me3:sicer
#   H3K36me3:sicer
#
# All Tracks:
#   H3K4me1 [32], OD_OD4_H3K4me1_broad0.01_peaks.broadPeak..YD_YD20_H3K4me1_broad1.0E-6_peaks.broadPeak
#   H3K4me3 [40], OD_OD1_H3K4me3_broad0.01_peaks.broadPeak..YD_YD21_H3K4me3_broad0.01_peaks.broadPeak
#   H3K27ac [40], OD_OD1_H3K27ac_broad1.0E-4_peaks.broadPeak..YD_YD21_H3K27ac_broad1.0E-6_peaks.broadPeak
#   H3K27me3 [40], OD_OD1_H3K27me3-W200-G200-FDR1.0E-8-island.bed..YD_YD21_H3K27me3-W200-G600-FDR1.0E-8-island.bed
#   H3K36me3 [39], OD_OD1_H3K36me3-W200-G600-FDR1.0E-8-island.bed..YD_YD21_H3K36me3-W200-G1200-FDR1.0E-8-island.bed
#
# All donors paths: (first 5) or 191
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD4_H3K4me1_broad0.01_peaks.broadPeak
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD5_H3K4me1_broad0.01_peaks.broadPeak
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD6_H3K4me1_broad0.01_peaks.broadPeak
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD7_H3K4me1_broad0.01_peaks.broadPeak
#     /mnt/stripe/bio/experiments/configs/benchmark/benchmark/H3K4me1/macs_broad/OD_OD8_H3K4me1_broad1.0E-4_peaks.broadPeak
#
# Metrics table:
# /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_im_golden.csv
# [Skipped]: Already exists /mnt/stripe/bio/experiments/configs/benchmark/benchmark/fig8_wo_failed_im_golden.csv
#
# Use only passed (not failed) tracks
#   H3K27ac: 38 or 40
#   H3K27me3: 32 or 40
#   H3K36me3: 32 or 39
#   H3K4me1: 32 or 32
#   H3K4me3: 33 or 40
# Passed tracks table: 167x167 of 191x191
# Columns: (first 5)
#     OD_OD4_H3K4me1_broad0.01_peaks.broadPeak
#     OD_OD5_H3K4me1_broad0.01_peaks.broadPeak
#     OD_OD6_H3K4me1_broad0.01_peaks.broadPeak
#     OD_OD7_H3K4me1_broad0.01_peaks.broadPeak
#     OD_OD8_H3K4me1_broad1.0E-4_peaks.broadPeak

# %% [markdown]
# ## Avg Depth Of Sequencing

# %%
# run LibDepthSummaryReport --all --config ./experiments/src/main/resources/datasets/Y20O20.yaml -o /mnt/stripe/bio/experiments/aging/Y20O20.all.libdepth.all.csv

#lib_depth_path = "/mnt/stripe/bio/experiments/aging/Y20O20.libdepth.csv"
# lib_depth_title = "Sequencing Depth (average and std) w/o failed tracks"

lib_depth_path = "/mnt/stripe/bio/experiments/aging/Y20O20.libdepth.all.csv"
lib_depth_title = "Sequencing Depth (average and std)"

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_lib_depth(lib_depth_path,  title,
                   donor_labels = True,
                   plot_path=None):
    df = pd.read_csv(lib_depth_path, sep="\t", comment="#", index_col=None)
    df = df.drop("Input", axis=1)
    df = pd.melt(df, var_name='hist', value_name='depth', id_vars=["donor"])
    df["age"] = "Young"
    df.loc[df.donor.str.startswith("OD"), "age"] = "Old"
    df["depth"] = df["depth"]/1000000
    hist_mods = ["H3K4me1", "H3K4me3", "H3K27ac", "H3K27me3", "H3K36me3"]

    import matplotlib.pyplot as plt
    import seaborn as sns
    plt.figure(figsize=(8,6))
    sns.set_style("whitegrid")
    #hue=age,  order=["H3K4me1", .. "Lunch"], ci=68 confidence interval, estimator=np.median, color="salmon", saturation=.5
    # errcolor="red", errwidth=0.3
    ax = sns.barplot(data=df, 
                     x="hist", y="depth",
                     order=hist_mods,
                     ci="sd", capsize=.2, errwidth=2, # error bars
                     # hue="age",
                     # facecolor=(1, 1, 1, 0), # do not fill with color
                     color="lightgray",
                     edgecolor="black")

    age_palette={"Young":"red", "Old": "blue"}
    # swarmplot: no intersection, stripplot: intersected
    ax = sns.swarmplot(data=df, 
                  x="hist", y="depth",
                  size=5, 
                  order=hist_mods,
                  linewidth=1, # edge line width
                  hue = "age",
                  palette=age_palette,
                  #jitter=True
                 )

    if donor_labels:
        for i, h in enumerate(hist_mods):
            hdf = df[df["hist"] == h].dropna()
        #     l_min, l_max = np.percentile(hdf["depth"], q=[25, 75])
            l_min = np.mean(hdf["depth"]) - np.std(hdf["depth"])
            l_max = np.mean(hdf["depth"]) + np.std(hdf["depth"])
        #     print(h, l_min, l_max)
            for donor, depth, age in zip(hdf["donor"].tolist(), hdf["depth"].tolist(), hdf["age"]):
                if depth < l_min or depth > l_max:
                    ax.text(i, depth, donor, color=age_palette[age], fontsize=8)

    plt.title(title)
    # plt.ticklabel_format(style='plain', axis='y',useOffset=True)
    plt.ylabel("Millions Reads")
    plt.xlabel("")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
    bm.save_plot(plot_path)

# %% [markdown]
# Final panel:

# %%
plot_lib_depth(lib_depth_path, lib_depth_title, donor_labels=False)

from matplotlib.backends.backend_pdf import PdfPages
with PdfPages(str(root_path / "fig1_panel_1.pdf")) as pdf:
    plot_lib_depth(lib_depth_path, lib_depth_title, donor_labels=False, plot_path=pdf)

# %% [markdown]
# ## Heatmap Tuned Zibra vs Chromhmm

# %% [markdown]
# Calculate intersection metrics manually or using all loci pipeline:
#
# ```
# #! python /mnt/stripe/washu/downstream/reports/loci_intersection_report.py -o /mnt/stripe/bio/experiments/aging/loci_of_interest/tuned8_plots -p 24 --skip-stats --tool zinbra
# ```

# %%
signal_at_loci_root = Path("/mnt/stripe/bio/experiments/aging/loci_of_interest/tuned8_plots")

# %%
ordered_hist = ['H3K4me1','H3K4me3', 'H3K27ac', 'H3K27me3', 'H3K36me3']
hist_to_order = {h: i for i,h in enumerate(ordered_hist)}

df = pd.DataFrame.from_csv(signal_at_loci_root / "chromhmm_encsr907lcd@weak_consensus_common.csv")
df.index = ["{1} ({0})".format(*r.split('.')[-2].split('_')) for r in df.index]

# %% [markdown]
# ### Main

# %%
fdf = df.loc[:, [c for c in df.columns if "zinbra" in c]]

fdf.columns = [c.split('_')[0] for c in fdf.columns]
fdf = fdf.loc[:, ordered_hist]

# %%
with PdfPages(str(root_path / "fig1_panel_12.pdf")) as pdf:
    for out in [None]:
        bm.plot_metric_heatmap(
            '', fdf.transpose(), figsize=(18, 6), cbar=False,
            save_to=out,
        )

# %% [markdown]
# ### Supplementary

# %%
fdf = df.copy()

def hist_and_tool(l):
    hist, tool = l.split('_')[:2]
    return "{}: {}".format(tool.upper(), hist)

fdf.columns = list(map(hist_and_tool, fdf.columns))
fdf = fdf.loc[:, sorted(fdf.columns, key=lambda c: (hist_to_order[c.split(' ')[1]], c))]

fdf.head()
# Out:
#               MACS: H3K4me1  ZINBRA: H3K4me1  MACS: H3K4me3  ZINBRA: H3K4me3  \
# TssA (1)           0.672430         0.909339       0.817872         0.827167
# TssFlnk (2)        0.581967         0.742424       0.475161         0.551416
# TssFlnkU (3)       0.965215         0.980047       0.408447         0.434683
# TssFlnkD (4)       0.971358         0.968961       0.161973         0.284436
# Tx (5)             0.202313         0.287179       0.000307         0.003400
#
#               MACS: H3K27ac  ZINBRA: H3K27ac  MACS: H3K27me3  SICER: H3K27me3  \
# TssA (1)           0.916961         0.894714        0.000992         0.043688
# TssFlnk (2)        0.344511         0.271610        0.006582         0.167039
# TssFlnkU (3)       0.825907         0.801024        0.000592         0.033134
# TssFlnkD (4)       0.191829         0.171467        0.002110         0.096091
# Tx (5)             0.041695         0.061511        0.000307         0.011288
#
#               ZINBRA: H3K27me3  SICER: H3K36me3  ZINBRA: H3K36me3
# TssA (1)              0.014687         0.766066          0.308793
# TssFlnk (2)           0.049305         0.461997          0.149404
# TssFlnkU (3)          0.010325         0.781791          0.356989
# TssFlnkD (4)          0.022856         0.636640          0.222741
# Tx (5)                0.002146         0.992363          0.972324

# %%
with PdfPages(str(root_path / "fig1_panel_12_supplementary.pdf")) as pdf:
    for out in [pdf, None]:
        bm.plot_metric_heatmap(
            "ChromHMM (ENCSR907LCD) @ Weak consensus for Tuned ZINBRA", fdf, figsize=(12, 10), cbar=False,
            save_to=out,
        )

# %% [markdown]
# # Lib Depth By Chr

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_lib_depth_by_chr(df, title, 
                          donor_labels = True,
                          cols = None,
                          plot_path=None):

    if cols is None:
        cols = df.columns.tolist()
        cols.remove("donor")

    df = pd.melt(df, var_name='chr', value_name='depth', id_vars=["donor"])
    df["age"] = "Young"
    df.loc[df.donor.str.startswith("OD"), "age"] = "Old"
    df["depth"] = df["depth"]/1000000

    import matplotlib.pyplot as plt
    import seaborn as sns
    plt.figure(figsize=(14,6))
    sns.set_style("whitegrid")
    #hue=age,  order=["H3K4me1", .. "Lunch"], ci=68 confidence interval, estimator=np.median, color="salmon", saturation=.5
    # errcolor="red", errwidth=0.3
    ax = sns.barplot(data=df, 
                     x="chr", y="depth",
                     order=cols,
                     ci="sd", capsize=.2, errwidth=2, # error bars
                     # hue="age",
                     # facecolor=(1, 1, 1, 0), # do not fill with color
                     color="lightgray",
                     edgecolor="black")

    age_palette={"Young":"red", "Old": "blue"}
    # swarmplot: no intersection, stripplot: intersected
    ax = sns.swarmplot(data=df, 
                  x="chr", y="depth",
                  size=3, #5
                  order=cols,
                  #linewidth=1, # edge line width
                  hue = "age",
                  palette=age_palette,
                  #jitter=True
                 )

    if donor_labels:
        for i, chr in enumerate(cols):
            hdf = df[df["chr"] == chr].dropna()
        #     l_min, l_max = np.percentile(hdf["depth"], q=[25, 75])
            l_min = np.mean(hdf["depth"]) - np.std(hdf["depth"])
            l_max = np.mean(hdf["depth"]) + np.std(hdf["depth"])
        #     print(h, l_min, l_max)
            for donor, depth, age in zip(hdf["donor"].tolist(), hdf["depth"].tolist(), hdf["age"]):
                if depth < l_min or depth > l_max:
                    ax.text(i, depth, donor, color=age_palette[age], fontsize=8)

    plt.title(title)
    # plt.ticklabel_format(style='plain', axis='y',useOffset=True)
    plt.ylabel("Millions Reads")
    plt.xlabel("")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
    bm.save_plot(plot_path)
    # plot.show

# %%
# run LibDepthSummaryReport --all --config ./experiments/src/main/resources/datasets/Y20O20.yaml --split -o /mnt/stripe/bio/experiments/aging/Y20O20.all.libdepth.all.bychrs.csv
lib_depth_path = "/mnt/stripe/bio/experiments/aging/Y20O20.all.libdepth.all.bychrs.csv"

# %%
df = pd.read_csv(lib_depth_path, sep="\t", comment="#", index_col=0)
df.head()
# Out:
#        H3K27ac_chr1  H3K27me3_chr1  H3K36me3_chr1  H3K4me1_chr1  H3K4me3_chr1  \
# donor
# OD1         2767860        4438059      5605645.0           NaN       3769926
# OD10        3865863        3925011      5340748.0     4967805.0       3106001
# OD11        1959868        4288217      3112330.0     4849641.0       3198710
# OD12        1903024        3888459      4122656.0     4236319.0       3564281
# OD13        2871828        3890339      4924427.0     5859619.0       3200471
#
#        Input_chr1  H3K27ac_chr2  H3K27me3_chr2  H3K36me3_chr2  H3K4me1_chr2  \
# donor
# OD1           NaN       2570588        4149384      4768111.0           NaN
# OD10          NaN       3391128        3950071      4418023.0     4052060.0
# OD11          NaN       1760967        4318772      2547375.0     4267619.0
# OD12          NaN       1662935        3863433      3454478.0     3564085.0
# OD13          NaN       2463117        3687950      4121079.0     4888911.0
#
#           ...       H3K36me3_chr22  H3K4me1_chr22  H3K4me3_chr22  Input_chr22  \
# donor     ...
# OD1       ...            1165895.0            NaN         579126          NaN
# OD10      ...            1188554.0      1145843.0         559107          NaN
# OD11      ...             718053.0       994104.0         543918          NaN
# OD12      ...             871053.0       907986.0         617087          NaN
# OD13      ...            1085829.0      1174895.0         562599          NaN
#
#        H3K27ac_chr21  H3K27me3_chr21  H3K36me3_chr21  H3K4me1_chr21  \
# donor
# OD1           407112          567528        679363.0            NaN
# OD10          542823          607867        657712.0       716069.0
# OD11          274967          620449        384473.0       723631.0
# OD12          262747          578950        502608.0       613821.0
# OD13          390588          505869        614577.0       816766.0
#
#        H3K4me3_chr21  Input_chr21
# donor
# OD1           573229          NaN
# OD10          466566          NaN
# OD11          483758          NaN
# OD12          531286          NaN
# OD13          465485          NaN
#
# [5 rows x 144 columns]

# %%
from itertools import groupby
from collections import defaultdict, OrderedDict

# %%
col_details = OrderedDict((t, t.split("_")) for t in df.columns)
by_hist = defaultdict(list)
for k, (hist, chr) in col_details.items():
    by_hist[hist].append((k, chr))

del by_hist["Input"]

# %%
import seaborn as sns
sns.set_style("whitegrid")

for hist, values in by_hist.items():
    cols, chrs = zip(*values)
    sdf = df.loc[:, cols]
    sdf.columns = chrs

    # version a)
    plt.figure(figsize=(20, 5))
    sns.boxplot(data=sdf)
    sns.stripplot(data=sdf, size=2, jitter=True, color="black")
    plt.title(hist)
    plt.show()
    
    # version b)
    sdf['donor'] = sdf.index
    plot_lib_depth_by_chr(sdf, "{}: Sequencing Depth (average and std)".format(hist), donor_labels=False)

# %% [markdown]
# ## Averaged by donor

# %%
# For peter:
# df = pd.read_csv(lib_depth_path, sep="\t", comment="#", index_col=0)
avg_df = pd.DataFrame(df.mean(), columns=["val"])
avg_df.loc[:, "hist"], avg_df.loc[:, "chr"] = list(zip(*avg_df.index.str.split("_")))
avg_df = avg_df.pivot(index='chr', columns='hist', values='val')
avg_df.drop("Input", axis=1)
#print(avg_df.head())

# plt.figure(figsize=(20, 5))
# sns.boxplot(data=avg_df.T)
# sns.stripplot(data=avg_df.T, size=2, jitter=True, color="black")
# plt.title(hist)
# plt.show()

tmp = avg_df.T
tmp["donor"] = tmp.index
plot_lib_depth_by_chr(tmp, "Sequencing Depth (average and std), data avareaged by donor".format(hist), donor_labels=True,
                      cols=list(OrderedDict([(s.split("_")[1], 1) for s in df.columns]).keys()))

# %% [markdown]
# # FRIP

# %%
hist_mods = OrderedDict([('H3K4me1', "zinbra"),
                         ('H3K4me3', "zinbra"),
                         ('H3K27ac', "zinbra"),
                         ('H3K27me3', "zinbra"),
                         ('H3K36me3', "zinbra")])
                        
print("Tools:")
print(*["  {}:{}".format(k, v) for k,v in hist_mods.items()], sep="\n")

# -----------------------------------
# Collect tracks:
for f in hfolders:
    match = re.match(".*/(H[^/]*)/([^/]*).*", f, flags=re.IGNORECASE)
    assert match
    hist = match.group(1)
    tool = match.group(2)

    if hist_mods[hist] != tool:
        continue

    tracks = loi.collect_peaks_in_folder(Path(f))
    rips = [p.with_suffix(".bed_rip.csv") for p in tracks]
    donors_and_tools = [bm.label_converter_donor_and_tool(p.name.replace("_rip.csv", "")) for p in rips]
    donors = [dt.split("_")[0] for dt in donors_and_tools]
    metrics = ["/mnt/stripe/bio/experiments/configs/Y20O20/unique/{}/{}_{}_{}_metrics.txt".format(hist, d[0:2], d, hist) for d in donors]
    
    for (r_path, m_path, d) in zip(rips, metrics, donors):
        m_df = pd.read_csv(m_path,  sep="\t", comment="#")
        usable_reads = m_df["UNPAIRED_READS_EXAMINED"][0] - m_df["UNPAIRED_READ_DUPLICATES"][0]
        
        r_df = pd.read_csv(r_path)
        print("{} {}: {} vs {}".format(hist, d, r_df["reads"][0], usable_reads))

# print("\nTracks Rip:")
# for h in hist_mods:
#     tracks = hist_2_rip[h]
#     assert tracks, "No tracks for {}".format(h)
#     print("  {} [{}], {}..{}".format(
#         h, len(tracks), Path(tracks[0]).name, Path(tracks[-1]).name)
#     )

# all_donors_paths = list(chain(*(hist_2_rip[h] for h in hist_mods)))
# print("\nAll donors rip paths: (first 5) or {}".format(len(all_donors_paths)),
#       *all_donors_paths[0:5], sep="\n    ")

# all_donors_labels = list(chain(
#     *([h + "_" + bm.label_converter_donor_and_tool(p.name.replace("_rip.csv", "")) for p in hist_2_rip[h]] for h in hist_mods)
# ))
                        
# # all_donors_labels
# print("\nAll donors short labels: (first 5) or {}".format(len(all_donors_labels)),
#           *all_donors_labels[0:5], sep="\n   ")

# all_donors_metrics = []
# for h in hist_mods:
#     donors = [bm.label_converter_donor_and_tool(p.name.replace("_rip.csv", "")).split("_")[0] for p in hist_2_rip[h]]
#     all_donors_metrics.extend(["/mnt/stripe/bio/experiments/configs/Y20O20/unique/{}/{}_{}_{}_metrics.txt".format(h, d[0:2], d, h) for d in donors])
    
# all_donors_metrics[0:5]
# Out:
# Tools:
#   H3K4me1:zinbra
#   H3K4me3:zinbra
#   H3K27ac:zinbra
#   H3K27me3:zinbra
#   H3K36me3:zinbra
# H3K27ac OD1: 31047948 vs 26719399
# H3K27ac OD2: 32039420 vs 25938427
# H3K27ac OD3: 42003647 vs 30051633
# H3K27ac OD4: 22221226 vs 16416829
# H3K27ac OD5: 26052628 vs 21301011
# H3K27ac OD6: 61154859 vs 38774491
# H3K27ac OD7: 78228522 vs 38573724
# H3K27ac OD8: 23309823 vs 19811522
# H3K27ac OD9: 42599940 vs 32244453
# H3K27ac OD10: 41258333 vs 28874631
# H3K27ac OD11: 21208749 vs 17849071
# H3K27ac OD12: 20406960 vs 16572668
# H3K27ac OD13: 30071428 vs 20705251
# H3K27ac OD14: 46941291 vs 34208321
# H3K27ac OD15: 21782163 vs 18297091
# H3K27ac OD16: 21891182 vs 20203087
# H3K27ac OD17: 18569397 vs 16027370
# H3K27ac OD18: 50074143 vs 36976861
# H3K27ac OD19: 33718868 vs 26904740
# H3K27ac OD20: 47903197 vs 36325756
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-71906e2a3f67> in <module>()
#      26
#      27     for (r_path, m_path, d) in zip(rips, metrics, donors):
# ---> 28         m_df = pd.read_csv(m_path,  sep="\t", comment="#")
#      29         usable_reads = m_df["UNPAIRED_READS_EXAMINED"][0] - m_df["UNPAIRED_READ_DUPLICATES"][0]
#      30
#
# /Users/romeo/anaconda/envs/aging3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /Users/romeo/anaconda/envs/aging3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /Users/romeo/anaconda/envs/aging3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     760             self.options['has_index_names'] = kwds['has_index_names']
#     761
# --> 762         self._make_engine(self.engine)
#     763
#     764     def close(self):
#
# /Users/romeo/anaconda/envs/aging3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     964     def _make_engine(self, engine='c'):
#     965         if engine == 'c':
# --> 966             self._engine = CParserWrapper(self.f, **self.options)
#     967         else:
#     968             if engine == 'python':
#
# /Users/romeo/anaconda/envs/aging3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1580         kwds['allow_leading_cols'] = self.index_col is not False
#    1581
# -> 1582         self._reader = parsers.TextReader(src, **kwds)
#    1583
#    1584         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'/mnt/stripe/bio/experiments/configs/Y20O20/unique/H3K27ac/YD_YD1_H3K27ac_metrics.txt' does not exist
