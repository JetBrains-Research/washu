# %% [markdown]
# # Aging project notebook
# Pipeline:
# * Process peak calling
# * Use `metapeaks.sh` script to compute number of overlapping peaks
# * Draw venn diagrams - `showvenn2` or `showvenn3` methods. Arguments order matches metapeaks output.

# %%
# %matplotlib inline
import pandas as pd
from matplotlib_venn import venn2
from matplotlib_venn import venn3
import matplotlib.pyplot as plt

def showvenn2(s1, s2, aB, Ab, AB):
    fig = plt.figure(figsize=(4, 4))
    venn2(subsets = (Ab, aB, AB), set_labels = (s1, s2))
    plt.show()

def showvenn3(s1, s2, s3, abC, aBc, aBC, Abc, AbC, ABc, ABC):
    fig = plt.figure(figsize=(4, 4))
    venn3(subsets = (Abc, aBc, ABc, abC, AbC, aBC, ABC), set_labels = (s1, s2, s3))
    plt.show()

# %% [markdown]
# # ENCODE k9me3
# ```
# $ QS=( 0.001 0.01 0.1 )
# for Q in ${QS[@]}; do bash ~/work/washu/metapeaks.sh encode_k9me3_control_macs_broad_${Q}/Broad_k9me3_1_ENCFF000CEI_hg19_${Q}_peaks.broadPeak encode_k9me3_control_macs_broad_${Q}/Broad_k9me3_2_ENCFF000CEJ_hg19_${Q}_peaks.broadPeak run_1916_1917_trim_bams_macs_broad_${Q}/63_donor8_k9me3_abcam_5_hg19_broad_${Q}_peaks.broadPeak; done
# ```
# Output:
# ```
# CHRFILES: encode_k9me3_control_macs_broad_0.001/Broad_k9me3_1_ENCFF000CEI_hg19_0.001_peaks.broadPeak.chr_only.tmp encode_k9me3_control_macs_broad_0.001/Broad_k9me3_2_ENCFF000CEJ_hg19_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.001/63_donor8_k9me3_abcam_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS: 24645 10002 46015
# 0	0	1	30654
# 0	1	0	764
# 0	1	1	406
# 1	0	0	10800
# 1	0	1	6020
# 1	1	0	1661
# 1	1	1	5675
# CHRFILES: encode_k9me3_control_macs_broad_0.01/Broad_k9me3_1_ENCFF000CEI_hg19_0.01_peaks.broadPeak.chr_only.tmp encode_k9me3_control_macs_broad_0.01/Broad_k9me3_2_ENCFF000CEJ_hg19_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.01/63_donor8_k9me3_abcam_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS: 43292 20058 72485
# 0	0	1	46338
# 0	1	0	2274
# 0	1	1	990
# 1	0	0	18819
# 1	0	1	9130
# 1	1	0	3972
# 1	1	1	10496
# CHRFILES: encode_k9me3_control_macs_broad_0.1/Broad_k9me3_1_ENCFF000CEI_hg19_0.1_peaks.broadPeak.chr_only.tmp encode_k9me3_control_macs_broad_0.1/Broad_k9me3_2_ENCFF000CEJ_hg19_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.1/63_donor8_k9me3_abcam_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS: 95577 46243 167537
# 0	0	1	98561
# 0	1	0	4272
# 0	1	1	2544
# 1	0	0	35193
# 1	0	1	23754
# 1	1	0	7296
# 1	1	1	26838
# ```

# %%
# Q = 0.001
showvenn3('encode_1', 'encode_2', '63_donor8_activemotif', 30654, 764, 406, 10800, 6020, 1661, 5675)
# Q = 0.01
showvenn3('encode_1', 'encode_2', '63_donor8_activemotif', 46338, 2274, 990, 18819, 9130, 3972, 10496)
# Q = 0.1
showvenn3('encode_1', 'encode_2', '63_donor8_activemotif', 98561, 4272, 2544, 35193, 23754, 7296, 26838)

# %% [markdown]
# # ENCODE k9me3
# ```
# $ QS=( 0.001 0.01 0.1 )
# for Q in ${QS[@]}; do bash ~/work/washu/metapeaks.sh encode_k9me3_control_macs_broad_${Q}/Broad_k9me3_1_ENCFF000CEI_hg19_${Q}_peaks.broadPeak run_1916_1917_trim_bams_macs_broad_${Q}/63_donor8_k9me3_abcam_5_hg19_broad_${Q}_peaks.broadPeak run_1916_1917_trim_bams_macs_broad_${Q}/64_donor8_k9me3_activemotif_5_hg19_broad_${Q}_peaks.broadPeak; done
# ```
# Output:
# ```
# CHRFILES: encode_k9me3_control_macs_broad_0.001/Broad_k9me3_1_ENCFF000CEI_hg19_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.001/63_donor8_k9me3_abcam_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.001/64_donor8_k9me3_activemotif_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS: 24645 46015 37998
# 0	0	1	8784
# 0	1	0	16702
# 0	1	1	13920
# 1	0	0	11669
# 1	0	1	775
# 1	1	0	2054
# 1	1	1	9718
# CHRFILES: encode_k9me3_control_macs_broad_0.01/Broad_k9me3_1_ENCFF000CEI_hg19_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.01/63_donor8_k9me3_abcam_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.01/64_donor8_k9me3_activemotif_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS: 43292 72485 79014
# 0	0	1	29822
# 0	1	0	24895
# 0	1	1	21280
# 1	0	0	20045
# 1	0	1	2734
# 1	1	0	3040
# 1	1	1	16706
# CHRFILES: encode_k9me3_control_macs_broad_0.1/Broad_k9me3_1_ENCFF000CEI_hg19_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.1/63_donor8_k9me3_abcam_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.1/64_donor8_k9me3_activemotif_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS: 95577 167537 170656
# 0	0	1	57439
# 0	1	0	60062
# 0	1	1	37753
# 1	0	0	33381
# 1	0	1	8736
# 1	1	0	8402
# 1	1	1	42511
# ```

# %%
# Q = 0.001
showvenn3('encode_1', '63_donor8_activemotif', '64_donor8_abcam', 8784, 16702, 13920, 11669, 775, 2054, 9718)
# Q = 0.01
showvenn3('encode_1', '63_donor8_activemotif', '64_donor8_abcam', 29822, 24895, 21280, 20045, 2734, 3040, 16706)
# Q = 0.1
showvenn3('encode_1', '63_donor8_activemotif', '64_donor8_abcam', 57439, 60062, 37753, 33381, 8736, 8402, 42511)

# %% [markdown]
# # k9me3
# ```
# $ QS=( 0.001 0.01 0.1 )
# for Q in ${QS[@]}; do bash ~/work/washu/metapeaks.sh run_1916_1917_trim_bams_macs_broad_${Q}/59_donor7_k9me3_abcam_5_hg19_broad_${Q}_peaks.broadPeak run_1916_1917_trim_bams_macs_broad_${Q}/63_donor8_k9me3_abcam_5_hg19_broad_${Q}_peaks.broadPeak run_1916_1917_trim_bams_macs_broad_${Q}/64_donor8_k9me3_activemotif_5_hg19_broad_${Q}_peaks.broadPeak; done```
# Output:
# ```
# CHRFILES: run_1916_1917_trim_bams_macs_broad_0.001/59_donor7_k9me3_abcam_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.001/63_donor8_k9me3_abcam_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.001/64_donor8_k9me3_activemotif_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS: 40136 46015 37998
# 0       0       1       10200
# 0       1       0       18330
# 0       1       1       22669
# 1       0       0       36509
# 1       0       1       23
# 1       1       0       1478
# 1       1       1       1962
# CHRFILES: run_1916_1917_trim_bams_macs_broad_0.01/59_donor7_k9me3_abcam_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.01/63_donor8_k9me3_abcam_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.01/64_donor8_k9me3_activemotif_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS: 43345 72485 79014
# 0       0       1       34120
# 0       1       0       27775
# 0       1       1       36537
# 1       0       0       38185
# 1       0       1       74
# 1       1       0       1699
# 1       1       1       3133
# CHRFILES: run_1916_1917_trim_bams_macs_broad_0.1/59_donor7_k9me3_abcam_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.1/63_donor8_k9me3_abcam_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.1/64_donor8_k9me3_activemotif_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS: 50522 167537 170656
# 0       0       1       74673
# 0       1       0       72488
# 0       1       1       77441
# 1       0       0       40981
# 1       0       1       141
# 1       1       0       2868
# 1       1       1       6033
# ```

# %%
# Q = 0.001
showvenn3('59_donor7_abcam', '63_donor8_activemotif', '64_donor8_abcam', 10200, 18330, 22669, 36509, 23, 1478, 1962)
# Q = 0.01
showvenn3('59_donor7_abcam', '63_donor8_activemotif', '64_donor8_abcam', 34120, 27775, 36537, 38185, 74, 1699, 3133)
# Q = 0.1
showvenn3('59_donor7_abcam', '63_donor8_activemotif', '64_donor8_abcam', 74673, 72488, 77441, 40981, 141, 2868, 6033)

# %% [markdown]
# # ENCODE k4me1
# ```
# $ for Q in ${QS[@]}; do bash ~/work/washu/metapeaks.sh encode_k4me1_bams_macs_broad_${Q}/Broad_1_ENCFF000CDL_hg19_${Q}_peaks.broadPeak encode_k4me1_bams_macs_broad_${Q}/Broad_2_ENCFF000CDK_hg19_${Q}_peaks.broadPeak; done
# ```
# Output:
# ```
# CHRFILES: encode_k4me1_bams_macs_broad_0.0000001/Broad_1_ENCFF000CDL_hg19_0.0000001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.0000001/Broad_2_ENCFF000CDK_hg19_0.0000001_peaks.broadPeak.chr_only.tmp
# PEAKS:    42704    39786
# 0	1	4414
# 1	0	8047
# 1	1	34006
# CHRFILES: encode_k4me1_bams_macs_broad_0.000001/Broad_1_ENCFF000CDL_hg19_0.000001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.000001/Broad_2_ENCFF000CDK_hg19_0.000001_peaks.broadPeak.chr_only.tmp
# PEAKS:    45891    42583
# 0	1	4197
# 1	0	8378
# 1	1	36800
# CHRFILES: encode_k4me1_bams_macs_broad_0.00001/Broad_1_ENCFF000CDL_hg19_0.00001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.00001/Broad_2_ENCFF000CDK_hg19_0.00001_peaks.broadPeak.chr_only.tmp
# PEAKS:    50222    47252
# 0	1	4404
# 1	0	8426
# 1	1	41000
# CHRFILES: encode_k4me1_bams_macs_broad_0.0001/Broad_1_ENCFF000CDL_hg19_0.0001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.0001/Broad_2_ENCFF000CDK_hg19_0.0001_peaks.broadPeak.chr_only.tmp
# PEAKS:    54166    51762
# 0	1	4672
# 1	0	8238
# 1	1	44994
# CHRFILES: encode_k4me1_bams_macs_broad_0.001/Broad_1_ENCFF000CDL_hg19_0.001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.001/Broad_2_ENCFF000CDK_hg19_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS:    58564    56398
# 0	1	4728
# 1	0	8239
# 1	1	49251
# CHRFILES: encode_k4me1_bams_macs_broad_0.01/Broad_1_ENCFF000CDL_hg19_0.01_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.01/Broad_2_ENCFF000CDK_hg19_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    64187    61716
# 0	1	4661
# 1	0	8866
# 1	1	54140
# CHRFILES: encode_k4me1_bams_macs_broad_0.1/Broad_1_ENCFF000CDL_hg19_0.1_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.1/Broad_2_ENCFF000CDK_hg19_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS:    71058    66465
# 0	1	4249
# 1	0	11452
# 1	1	58478
# ```

# %%
# Q = 0.0000001
showvenn2('encode_1', 'encode_2', 4414, 8047, 34006)
# Q = 0.000001
showvenn2('encode_1', 'encode_2', 4197, 8378, 36800)
# Q = 0.00001
showvenn2('encode_1', 'encode_2', 4404, 8426, 41000)
# Q = 0.0001
showvenn2('encode_1', 'encode_2', 4672, 8239, 49251)
# Q = 0.001
showvenn2('encode_1', 'encode_2', 4728, 8239, 49251)
# Q = 0.01
showvenn2('encode_1', 'encode_2', 4661, 8866, 54140)
# Q = 0.1
showvenn2('encode_1', 'encode_2', 4249, 11452, 58478)

# %% [markdown]
# # ENCODE k4me1 Q=0.01 vs run_1916_1917 different Qs
# ```
# $ QS=( 0.0000000001 0.000001 0.01 )
# $ for Q in ${QS[@]}; do bash ~/work/washu/metapeaks.sh encode_k4me1_bams_macs_broad_0.01/Broad_1_ENCFF000CDL_hg19_0.01_peaks.broadPeak run_1916_1917_k4me1_bams_macs_broad_${Q}/57_donor7_k4me1_5_hg19_${Q}_peaks.broadPeak run_1916_1917_k4me1_bams_macs_broad_${Q}/61_donor8_k4me1_5_hg19_${Q}_peaks.broadPeak; done
# ```
# Output
# ```
# CHRFILES: encode_k4me1_bams_macs_broad_0.01/Broad_1_ENCFF000CDL_hg19_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.0000000001/57_donor7_k4me1_5_hg19_0.0000000001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.0000000001/61_donor8_k4me1_5_hg19_0.0000000001_peaks.broadPeak.chr_only.tmp
# PEAKS:    64187    73808    83565
# 0	0	1	7123
# 0	1	0	1913
# 0	1	1	5008
# 1	0	0	9389
# 1	0	1	6243
# 1	1	0	1410
# 1	1	1	47007
# CHRFILES: encode_k4me1_bams_macs_broad_0.01/Broad_1_ENCFF000CDL_hg19_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.000001/57_donor7_k4me1_5_hg19_0.000001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.000001/61_donor8_k4me1_5_hg19_0.000001_peaks.broadPeak.chr_only.tmp
# PEAKS:    64187    97051   104756
# 0	0	1	12345
# 0	1	0	4835
# 0	1	1	15488
# 1	0	0	3203
# 1	0	1	3025
# 1	1	0	867
# 1	1	1	56476
# CHRFILES: encode_k4me1_bams_macs_broad_0.01/Broad_1_ENCFF000CDL_hg19_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.01/57_donor7_k4me1_5_hg19_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.01/61_donor8_k4me1_5_hg19_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    64187   131992   138847
# 0	0	1	21750
# 0	1	0	11609
# 0	1	1	42740
# 1	0	0	426
# 1	0	1	670
# 1	1	0	261
# 1	1	1	59747
# ```

# %%
# Q = 0.0000000001
showvenn3('encode', '57_donor7', '61_donor8', 7123, 1913, 5008, 9389, 6243, 1410, 47007)
# Q = 0.000001
showvenn3('encode', '57_donor7', '61_donor8', 12345, 4835, 15488, 3203, 3025, 867, 56476)
# Q = 0.01
showvenn3('encode', '57_donor7', '61_donor8', 21750, 11609, 42740, 426, 670, 261, 59747)

# %% [markdown]
# # VS ENCODE k4me1 + control SAME Qs
# ```
# $ QS=( 0.0000001 0.000001 0.00001 0.0001 0.001 0.01 0.1 )
# $ for Q in ${QS[@]}; do bash ~/work/washu/metapeaks.sh encode_k4me1_bams_macs_broad_${Q}/Broad_1_ENCFF000CDL_hg19_${Q}_peaks.broadPeak encode_k4me1_bams_macs_broad_${Q}/Broad_2_ENCFF000CDK_hg19_${Q}_peaks.broadPeak run_1916_1917_k4me1_bams_macs_broad_${Q}/66_donor6_k4me1_5_hg19_${Q}_peaks.broadPeak; done
# ```
# Output
# ```
# CHRFILES: encode_k4me1_bams_macs_broad_0.0000001/Broad_1_ENCFF000CDL_hg19_0.0000001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.0000001/Broad_2_ENCFF000CDK_hg19_0.0000001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.0000001/66_donor6_k4me1_5_hg19_0.0000001_peaks.broadPeak.chr_only.tmp
# PEAKS:    42704    39786    68093
# 0	0	1	19434
# 0	1	0	2175
# 0	1	1	2162
# 1	0	0	2361
# 1	0	1	5569
# 1	1	0	4456
# 1	1	1	29559
# CHRFILES: encode_k4me1_bams_macs_broad_0.000001/Broad_1_ENCFF000CDL_hg19_0.000001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.000001/Broad_2_ENCFF000CDK_hg19_0.000001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.000001/66_donor6_k4me1_5_hg19_0.000001_peaks.broadPeak.chr_only.tmp
# PEAKS:    45891    42583    75735
# 0	0	1	22197
# 0	1	0	1928
# 0	1	1	2184
# 1	0	0	2102
# 1	0	1	6137
# 1	1	0	3907
# 1	1	1	32880
# CHRFILES: encode_k4me1_bams_macs_broad_0.00001/Broad_1_ENCFF000CDL_hg19_0.00001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.00001/Broad_2_ENCFF000CDK_hg19_0.00001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.00001/66_donor6_k4me1_5_hg19_0.00001_peaks.broadPeak.chr_only.tmp
# PEAKS:    50222    47252    85030
# 0	0	1	25338
# 0	1	0	1734
# 0	1	1	2544
# 1	0	0	1787
# 1	0	1	6460
# 1	1	0	3547
# 1	1	1	37382
# CHRFILES: encode_k4me1_bams_macs_broad_0.0001/Broad_1_ENCFF000CDL_hg19_0.0001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.0001/Broad_2_ENCFF000CDK_hg19_0.0001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.0001/66_donor6_k4me1_5_hg19_0.0001_peaks.broadPeak.chr_only.tmp
# PEAKS:    54166    51762    94364
# 0	0	1	28679
# 0	1	0	1595
# 0	1	1	2936
# 1	0	0	1550
# 1	0	1	6507
# 1	1	0	3094
# 1	1	1	41737
# CHRFILES: encode_k4me1_bams_macs_broad_0.001/Broad_1_ENCFF000CDL_hg19_0.001_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.001/Broad_2_ENCFF000CDK_hg19_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.001/66_donor6_k4me1_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS:    58564    56398   105286
# 0	0	1	33139
# 0	1	0	1393
# 0	1	1	3186
# 1	0	0	1417
# 1	0	1	6550
# 1	1	0	2537
# 1	1	1	46478
# CHRFILES: encode_k4me1_bams_macs_broad_0.01/Broad_1_ENCFF000CDL_hg19_0.01_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.01/Broad_2_ENCFF000CDK_hg19_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.01/66_donor6_k4me1_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    64187    61716   128799
# 0	0	1	50288
# 0	1	0	930
# 0	1	1	3495
# 1	0	0	1094
# 1	0	1	7288
# 1	1	0	1584
# 1	1	1	51790
# CHRFILES: encode_k4me1_bams_macs_broad_0.1/Broad_1_ENCFF000CDL_hg19_0.1_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.1/Broad_2_ENCFF000CDK_hg19_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.1/66_donor6_k4me1_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS:    71058    66465   154430
# 0	0	1	69223
# 0	1	0	729
# 0	1	1	3195
# 1	0	0	1182
# 1	0	1	9438
# 1	1	0	1029
# 1	1	1	56156
# ```

# %%
# Q = 0.000001
showvenn3('encode_1', 'encode_2', '66_donor7', 19434, 2175, 2162, 2361, 5569, 4456, 29559)
# Q = 0.000001
showvenn3('encode_1', 'encode_2', '66_donor7', 22197, 1928, 2184, 2102, 6137, 3907, 32880)
# Q = 0.00001
showvenn3('encode_1', 'encode_2', '66_donor7', 25338, 1734, 2544, 1787, 6460, 3547, 37382)
# Q = 0.0001
showvenn3('encode_1', 'encode_2', '66_donor7', 28679, 1595, 2936, 1550, 6507, 3094, 41737)
# Q = 0.001
showvenn3('encode_1', 'encode_2', '66_donor7', 33139, 1393, 3186, 1417, 6550, 2537, 46478)
# Q = 0.01
showvenn3('encode_1', 'encode_2', '66_donor7', 50288, 930, 3495, 1094, 7288, 1584, 51790)
# Q = 0.1
showvenn3('encode_1', 'encode_2', '66_donor7', 69223, 729, 3195, 1182, 9438, 1029, 56156)

# %% [markdown]
# # VS ENCODE without control
# ```
# CHRFILES: encode_k4me1_bams_macs_broad_0.01/Broad_1_ENCFF000CDL_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.01/Broad_2_ENCFF000CDK_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.01/57_donor7_k4me1_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    61507    62370   131992
# 0	0	1	63627
# 0	1	0	733
# 0	1	1	7004
# 1	0	0	453
# 1	0	1	6873
# 1	1	0	494
# 1	1	1	50121
# CHRFILES: encode_k4me1_bams_macs_broad_0.01/Broad_1_ENCFF000CDL_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.01/Broad_2_ENCFF000CDK_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.01/61_donor8_k4me1_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    61507    62370   138847
# 0	0	1	71118
# 0	1	0	428
# 0	1	1	7144
# 1	0	0	293
# 1	0	1	6881
# 1	1	0	299
# 1	1	1	49931
# CHRFILES: encode_k4me1_bams_macs_broad_0.01/Broad_1_ENCFF000CDL_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp encode_k4me1_bams_macs_broad_0.01/Broad_2_ENCFF000CDK_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_trim_bams_macs_broad_0.01/66_donor6_k4me1_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    61507    62370   128799
# 0	0	1	61421
# 0	1	0	1214
# 0	1	1	6813
# 1	0	0	915
# 1	0	1	6591
# 1	1	0	1475
# 1	1	1	49509
# ```

# %%
# Q = 0.01
showvenn3('encode_1', 'encode_2', '57_donor7', 63627, 733, 7004, 453, 6873, 494, 50121)
# Q = 0.01
showvenn3('encode_1', 'encode_2', '61_donor8', 71118, 428, 7144, 293, 6881, 299, 49931)
# Q = 0.01
showvenn3('encode_1', 'encode_2', '66_donor6', 61421, 1214, 6813, 915, 6591, 1475, 49509)

# %% [markdown]
# # K4me1 subsampled to 30mln reads
# ```
# CHRFILES: 57_donor7_k4me1_5_hg19_30mln_broad_0.1_peaks.broadPeak.chr_only.tmp 61_donor8_k4me1_5_hg19_30mln_broad_0.1_peaks.broadPeak.chr_only.tmp 66_donor6_k4me1_5_hg19_30mln_broad_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS:   131798   132950   117497
# 0	0	1	4768
# 0	1	0	16719
# 0	1	1	4656
# 1	0	0	15479
# 1	0	1	2678
# 1	1	0	15345
# 1	1	1	89247
# CHRFILES: 57_donor7_k4me1_5_hg19_30mln_broad_0.01_peaks.broadPeak.chr_only.tmp 61_donor8_k4me1_5_hg19_30mln_broad_0.01_peaks.broadPeak.chr_only.tmp 66_donor6_k4me1_5_hg19_30mln_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:   115592   117215   104386
# 0	0	1	4574
# 0	1	0	13555
# 0	1	1	4371
# 1	0	0	12012
# 1	0	1	2784
# 1	1	0	13746
# 1	1	1	80042
# CHRFILES: 57_donor7_k4me1_5_hg19_30mln_broad_0.001_peaks.broadPeak.chr_only.tmp 61_donor8_k4me1_5_hg19_30mln_broad_0.001_peaks.broadPeak.chr_only.tmp 66_donor6_k4me1_5_hg19_30mln_broad_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS:    98242   102849    92920
# 0	0	1	5192
# 0	1	0	11716
# 0	1	1	5328
# 1	0	0	7885
# 1	0	1	2646
# 1	1	0	10659
# 1	1	1	70884
# ```

# %%
# Q = 0.1
showvenn3('57_donor7_30mln', '61_donor8_30mln', '66_donor6_30mln', 4768, 16719, 4656, 15479, 2678, 15345, 89247)
# Q = 0.01
showvenn3('57_donor7_30mln', '61_donor8_30mln', '66_donor6_30mln', 4574, 13555, 4371, 12012, 2784, 13746, 80042)
# Q = 0.001
showvenn3('57_donor7_30mln', '61_donor8_30mln', '66_donor6_30mln', 5192, 11716, 5328, 7885, 2646, 10659, 70884)

# %% [markdown]
# # k4me1
# ```
# $ QS= (  )
# $ for Q in ${QS[@]}; do bash ~/work/washu/metapeaks.sh run_1916_1917_k4me1_bams_macs_broad_${Q}/57_donor7_k4me1_5_hg19_${Q}_peaks.broadPeak run_1916_1917_k4me1_bams_macs_broad_${Q}/61_donor8_k4me1_5_hg19_${Q}_peaks.broadPeak run_1916_1917_k4me1_bams_macs_broad_${Q}/66_donor6_k4me1_5_hg19_${Q}_peaks.broadPeak; done
# ```
# Output:
# ```
# CHRFILES: run_1916_1917_k4me1_bams_macs_broad_0.0000001/57_donor7_k4me1_5_hg19_0.0000001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.0000001/61_donor8_k4me1_5_hg19_0.0000001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.0000001/66_donor6_k4me1_5_hg19_0.0000001_peaks.broadPeak.chr_only.tmp
# PEAKS:    90589    98152    68093
# 0	0	1	687
# 0	1	0	15056
# 0	1	1	1609
# 1	0	0	6354
# 1	0	1	437
# 1	1	0	24652
# 1	1	1	54589
# CHRFILES: run_1916_1917_k4me1_bams_macs_broad_0.000001/57_donor7_k4me1_5_hg19_0.000001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.000001/61_donor8_k4me1_5_hg19_0.000001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.000001/66_donor6_k4me1_5_hg19_0.000001_peaks.broadPeak.chr_only.tmp
# PEAKS:    97051   104756    75735
# 0	0	1	824
# 0	1	0	15912
# 0	1	1	1785
# 1	0	0	6370
# 1	0	1	508
# 1	1	0	24273
# 1	1	1	60528
# CHRFILES: run_1916_1917_k4me1_bams_macs_broad_0.00001/57_donor7_k4me1_5_hg19_0.00001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.00001/61_donor8_k4me1_5_hg19_0.00001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.00001/66_donor6_k4me1_5_hg19_0.00001_peaks.broadPeak.chr_only.tmp
# PEAKS:   105375   110739    85030
# 0	0	1	1212
# 0	1	0	14493
# 0	1	1	2017
# 1	0	0	8096
# 1	0	1	782
# 1	1	0	23108
# 1	1	1	68082
# CHRFILES: run_1916_1917_k4me1_bams_macs_broad_0.0001/57_donor7_k4me1_5_hg19_0.0001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.0001/61_donor8_k4me1_5_hg19_0.0001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.0001/66_donor6_k4me1_5_hg19_0.0001_peaks.broadPeak.chr_only.tmp
# PEAKS:   112353   117953    94364
# 0	0	1	1679
# 0	1	0	15038
# 0	1	1	2439
# 1	0	0	8519
# 1	0	1	996
# 1	1	0	21567
# 1	1	1	75348
# CHRFILES: run_1916_1917_k4me1_bams_macs_broad_0.001/57_donor7_k4me1_5_hg19_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.001/61_donor8_k4me1_5_hg19_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.001/66_donor6_k4me1_5_hg19_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS:   122216   128054   105286
# 0	0	1	2215
# 0	1	0	16994
# 0	1	1	2881
# 1	0	0	9540
# 1	0	1	1159
# 1	1	0	21417
# 1	1	1	82665
# CHRFILES: run_1916_1917_k4me1_bams_macs_broad_0.01/57_donor7_k4me1_5_hg19_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.01/61_donor8_k4me1_5_hg19_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.01/66_donor6_k4me1_5_hg19_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:   131992   138847   128799
# 0	0	1	8365
# 0	1	0	16214
# 0	1	1	6259
# 1	0	0	9300
# 1	0	1	2466
# 1	1	0	14042
# 1	1	1	95974
# CHRFILES: run_1916_1917_k4me1_bams_macs_broad_0.1/57_donor7_k4me1_5_hg19_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.1/61_donor8_k4me1_5_hg19_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_k4me1_bams_macs_broad_0.1/66_donor6_k4me1_5_hg19_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS:   157749   159160   154430
# 0	0	1	13218
# 0	1	0	17459
# 0	1	1	6460
# 1	0	0	17793
# 1	0	1	3998
# 1	1	0	16694
# 1	1	1	107528
# ```

# %%
# Q = 0.0000001
showvenn3('donor8', 'donor7', 'donor6', 687, 15056, 1609, 6354, 437, 24652, 54589)
# Q = 0.000001
showvenn3('donor8', 'donor7', 'donor6', 824, 15912, 1785, 6370, 508, 24273, 60528)
# Q = 0.00001
showvenn3('donor8', 'donor7', 'donor6', 1212, 14493, 2017, 8096, 782, 23108, 68982)
# Q = 0.0001
showvenn3('donor8', 'donor7', 'donor6', 1679, 15038, 2439, 8519, 996, 21567, 75348)
# Q = 0.001
showvenn3('donor8', 'donor7', 'donor6', 2215, 9540, 1159, 16994, 2881, 21417, 82665)
# Q = 0.01
showvenn3('donor8', 'donor7', 'donor6', 8365, 9300, 2466, 16214, 6259, 14042, 95974)
# Q = 0.1
showvenn3('donor8', 'donor7', 'donor6', 13218, 17793, 3998, 17459, 6460, 16694, 107528)

# %% [markdown]
# # K4me3 overlap
# ```
# QS=( 0.001 0.01 0.1)
# for Q in ${QS[@]}; do
#         bash ~/work/washu/metapeaks.sh encode_bams_macs_broad_${Q}/UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_broad_${Q}_peaks.broadPeak run_6_run_7_trim_bams_macs_broad_${Q}/donor8_k4me3_5_hg19_broad_${Q}_peaks.broadPeak run_1916_1917_deep_trim_bams_macs_broad_${Q}/46_donor8_k4me3_5_hg19_broad_${Q}_peaks.broadPeak
# done
# ```
# Output:
# ```
# CHRFILES: encode_bams_macs_broad_0.001/UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp run_6_run_7_trim_bams_macs_broad_0.001/donor8_k4me3_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_deep_trim_bams_macs_broad_0.001/46_donor8_k4me3_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS:    23488    25280    34285
# 0	0	1	10419
# 0	1	0	873
# 0	1	1	4545
# 1	0	0	4456
# 1	0	1	3460
# 1	1	0	149
# 1	1	1	15087
# CHRFILES: encode_bams_macs_broad_0.01/UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_6_run_7_trim_bams_macs_broad_0.01/donor8_k4me3_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_deep_trim_bams_macs_broad_0.01/46_donor8_k4me3_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    25128    30457    48569
# 0	0	1	20900
# 0	1	0	1781
# 0	1	1	6259
# 1	0	0	3793
# 1	0	1	3899
# 1	1	0	163
# 1	1	1	16822
# CHRFILES: encode_bams_macs_broad_0.1/UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp run_6_run_7_trim_bams_macs_broad_0.1/donor8_k4me3_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_deep_trim_bams_macs_broad_0.1/46_donor8_k4me3_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS:    27149    57587    98673
# 0	0	1	56666
# 0	1	0	11948
# 0	1	1	16960
# 1	0	0	2339
# 1	0	1	3253
# 1	1	0	285
# 1	1	1	20585
# ```

# %%
# Q=0.1
showvenn3('Encode_UW', 'donor8', 'donor8_deep', 56666, 11948, 16960, 2339, 3253, 285, 20585)
# Q=0.01
showvenn3('Encode_UW', 'donor8', 'donor8_deep', 20900, 1781, 6259, 3793, 3899, 163, 16822)
# Q=0.001
showvenn3('Encode_UW', 'donor8', 'donor8_deep', 10419, 873, 4545, 4456, 3460, 149, 15087)

# %% [markdown]
# # K4me3 donor8 overlap
# ```
# QS=( 0.01)
# for Q in ${QS[@]}; do bash ~/work/washu/metapeaks.sh run_6_run_7_trim_bams_macs_broad_${Q}/donor8_k4me3_5_hg19_broad_${Q}_peaks.broadPeak run_1916_1917_deep_trim_bams_macs_broad_${Q}/46_donor8_k4me3_5_hg19_broad_${Q}_peaks.broadPeak run_1916_1917_xnchip_bams_macs_broad_${Q}/51_donor8_k4me3_hg19_broad_${Q}_peaks.broadPeak; done
# ```
# Output:
# ```
# CHRFILES: run_6_run_7_trim_bams_macs_broad_0.01/donor8_k4me3_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_deep_trim_bams_macs_broad_0.01/46_donor8_k4me3_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.01/51_donor8_k4me3_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    30457    48569      231
# 0	0	1	203
# 0	1	0	25048
# 1	0	0	1973
# 1	1	0	23268
# 1	1	1	27
# ```

# %%
# Q=0.01
showvenn3('donor8', 'donor8_deep', 'donor8_xnchip', 203, 25048, 0, 1973, 0, 23268, 27)

# %% [markdown]
# # K27ac overlap deep vs xnchip
# ```
# QS=( 0.001 0.01 0.1)
# for Q in ${QS[@]}; do bash ~/work/washu/metapeaks.sh run_1916_1917_deep_trim_bams_macs_broad_${Q}/45_donor8_k27ac_5_hg19_broad_${Q}_peaks.broadPeak run_1916_1917_xnchip_bams_macs_broad_${Q}/50_donor8_k27ac_hg19_broad_${Q}_peaks.broadPeak run_1916_1917_xnchip_bams_macs_broad_${Q}/52_donor8_k27ac_hg19_broad_${Q}_peaks.broadPeak; done
# ```
# Output:
# ```
# CHRFILES: run_1916_1917_deep_trim_bams_macs_broad_0.001/45_donor8_k27ac_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.001/50_donor8_k27ac_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.001/52_donor8_k27ac_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS:    57820     6691     9566
# 0	0	1	34
# 0	1	0	132
# 0	1	1	37
# 1	0	0	47796
# 1	0	1	4007
# 1	1	0	982
# 1	1	1	5020
# CHRFILES: run_1916_1917_deep_trim_bams_macs_broad_0.01/45_donor8_k27ac_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.01/50_donor8_k27ac_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.01/52_donor8_k27ac_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    87594     8326    11909
# 0	0	1	58
# 0	1	0	266
# 0	1	1	51
# 1	0	0	75469
# 1	0	1	4849
# 1	1	0	1131
# 1	1	1	6126
# CHRFILES: run_1916_1917_deep_trim_bams_macs_broad_0.1/45_donor8_k27ac_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.1/50_donor8_k27ac_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.1/52_donor8_k27ac_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS:   154207    11290    17401
# 0	0	1	843
# 0	1	0	968
# 0	1	1	73
# 1	0	0	138511
# 1	0	1	6700
# 1	1	0	1095
# 1	1	1	7879
# ```

# %%
# Q=0.1
showvenn3('donor8_deep', 'donor8_xchip', 'donor8_nchip', 843, 968, 73, 138511, 6700, 1095, 7879)
# Q=0.01
showvenn3('donor8_deep', 'donor8_xchip', 'donor8_nchip', 58, 266, 51, 75469, 4849, 1131, 6126)
# Q=0.001
showvenn3('donor8_deep', 'donor8_xchip', 'donor8_nchip', 34, 132, 37, 47796, 4007, 982, 5020)

# %% [markdown]
# # k27ac deep vs uli vs nchip
# ```
# CHRFILES: run_1916_1917_xnchip_bams_macs_broad_0.01/50_donor8_k27ac_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.01/52_donor8_k27ac_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_6_run_7_trim_bams_macs_broad_0.01/donor8_k27ac_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:     8326    11909    62929
# 0	0	1	50653
# 0	1	0	183
# 0	1	1	4841
# 1	0	0	268
# 1	0	1	1197
# 1	1	0	54
# 1	1	1	6172
# CHRFILES: run_1916_1917_deep_trim_bams_macs_broad_0.01/45_donor8_k27ac_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.01/52_donor8_k27ac_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_6_run_7_trim_bams_macs_broad_0.01/donor8_k27ac_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    87594    11909    62929
# 0	0	1	8978
# 0	1	0	105
# 1	0	0	39245
# 1	0	1	36039
# 1	1	0	80
# 1	1	1	10881
# ```

# %%
# Q=0.01
showvenn3('donor8_xchip', 'donor8_nchip', 'donor8_uli', 50653, 183, 4841, 268, 1197, 54, 6172)
showvenn3('donor8_deep', 'donor8_nchip', 'donor8_uli', 8978, 105, 0, 39245, 36039, 80, 10881)

# %% [markdown]
# # k27ac vs ENCODE ChIP-Seq
# ```
# CHRFILES: encode_k27ac_bams_macs_broad_0.01/Broad_1_ENCFF000CEN_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp encode_k27ac_bams_macs_broad_0.01/Broad_2_ENCFF000CEO_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.01/52_donor8_k27ac_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    37447    37652    11909
# 0	0	1	473
# 0	1	0	4406
# 0	1	1	141
# 1	0	0	4633
# 1	0	1	55
# 1	1	0	21817
# 1	1	1	10872
# CHRFILES: encode_k27ac_bams_macs_broad_0.01/Broad_1_ENCFF000CEN_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp encode_k27ac_bams_macs_broad_0.01/Broad_2_ENCFF000CEO_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_deep_trim_bams_macs_broad_0.01/45_donor8_k27ac_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    37447    37652    87594
# 0	0	1	51730
# 0	1	0	1710
# 0	1	1	2567
# 1	0	0	1602
# 1	0	1	2752
# 1	1	0	1756
# 1	1	1	29773
# CHRFILES: encode_k27ac_bams_macs_broad_0.01/Broad_1_ENCFF000CEN_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp encode_k27ac_bams_macs_broad_0.01/Broad_2_ENCFF000CEO_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_6_run_7_trim_bams_macs_broad_0.01/donor8_k27ac_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    37447    37652    62929
# 0	0	1	29933
# 0	1	0	2576
# 0	1	1	1821
# 1	0	0	2461
# 1	0	1	2028
# 1	1	0	3972
# 1	1	1	28045
# CHRFILES: encode_k27ac_bams_macs_broad_0.01/Broad_1_ENCFF000CEN_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_1916_1917_xnchip_bams_macs_broad_0.01/52_donor8_k27ac_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp run_6_run_7_trim_bams_macs_broad_0.01/donor8_k27ac_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    37447    11909    62929
# 0	0	1	31672
# 0	1	0	132
# 0	1	1	342
# 1	0	0	6497
# 1	0	1	19291
# 1	1	0	74
# 1	1	1	10671
# ```

# %%
# Q=0.01
showvenn3('encode_1', 'encode_2', 'donor8_nchip', 473, 4406, 141, 4633, 55, 21817, 10872)
showvenn3('encode_1', 'encode_2', 'donor8_deep', 51730, 1710, 2567, 1602, 2752, 1756, 29773)
showvenn3('encode_1', 'encode_2', 'donor8_uli', 29933, 2575, 1821, 2461, 2028, 3972, 28045)
showvenn3('encode_1', 'donor8_nchip', 'donor8_uli', 31672, 132, 342, 6497, 19291, 74, 10671)

# %% [markdown]
# # ChIP-Seq Peaks analysis
# * Donor6
# * Donor7
# * Donor8

# %% [markdown]
# # Peaks intersection - by length

# %%
# %matplotlib inline
import pandas as pd
from matplotlib_venn import venn3
import matplotlib.pyplot as plt

def len2(df):
    return (df.end - df.start).sum()

def processvenn3(file):
    df = pd.read_csv(file, sep='\t')
    donor6 = df.columns[5]
    donor7 = df.columns[6]
    donor8 = df.columns[7]
    fig = plt.figure(figsize=(4, 4))
    # (Abc, aBc, ABc, abC, AbC, aBC, ABC)
    print(donor6, len2(df[df.list.apply(lambda x: '1' in x)]))
    print(donor7, len2(df[df.list.apply(lambda x: '2' in x)]))
    print(donor8, len2(df[df.list.apply(lambda x: '3' in x)]))
    Abc = len2(df[df.list == '1'])
    aBc = len2(df[df.list == '2'])
    ABc = len2(df[df.list == '1,2'])
    abC = len2(df[df.list == '3'])
    AbC = len2(df[df.list == '1,3'])
    aBC = len2(df[df.list == '2,3'])
    ABC = len2(df[df.list == '1,2,3'])
    venn3(subsets = (Abc, aBc, ABc, abC, AbC, aBC, ABC), set_labels = (donor6, donor7, donor8))
    plt.show()

# %% [markdown]
# # Peaks intersection length
#
# Please ensure that you have created intersection data by calling
# ```
# multiIntersectBed -header -i *k27ac*.bed > k27ac.csv
# multiIntersectBed -header -i *k4me3*.bed > k4me3.csv
# multiIntersectBed -header -i *k27me3*.bed > k27me3.csv
# ```

# %%
processvenn3('/mnt/washu/oshpynov/run_1901_6_7_trim_bams_macs_0.001/k4me3.csv')
processvenn3('/mnt/washu/oshpynov/run_1901_6_7_trim_bams_macs_0.01/k4me3.csv')
processvenn3('/mnt/washu/oshpynov/run_1901_6_7_trim_bams_macs_0.1/k4me3.csv')
# Out:
# donor6_k4me3_5_hg19_0.001_peaks.bed 4948612
# donor7_k4me3_5_hg19_0.001_peaks.bed 8005809
# donor8_k4me3_5_hg19_0.001_peaks.bed 11772813
# donor6_k4me3_5_hg19_0.01_peaks.bed 9726997
# donor7_k4me3_5_hg19_0.01_peaks.bed 13183308
# donor8_k4me3_5_hg19_0.01_peaks.bed 17112385
# donor6_k4me3_5_hg19_0.1_peaks.bed 18336232
# donor7_k4me3_5_hg19_0.1_peaks.bed 24079283
# donor8_k4me3_5_hg19_0.1_peaks.bed 31592272

# %% [markdown]
# # Broad peaks
# `multiIntersectBed -header -i *k4me3*.broadPeak > k4me3.csv`

# %%
processvenn3('/mnt/washu/artyomov_lab_aging/run_6_run_7_trim_bams_macs_broad_0.001/k4me3.csv')
processvenn3('/mnt/washu/artyomov_lab_aging/run_6_run_7_trim_bams_macs_broad_0.01/k4me3.csv')
processvenn3('/mnt/washu/artyomov_lab_aging/run_6_run_7_trim_bams_macs_broad_0.1/k4me3.csv')
processvenn3('/mnt/washu/artyomov_lab_aging/run_6_run_7_trim_bams_subsampled_macs_broad_0.1/k4me3.csv')

# %% [markdown]
# # ENCODE Broad k4me3 peaks intersection
# ```
# # For all
# multiIntersectBed -header -i Broad*k4me3*.bed > Broadk4me3.csv
#
# # 0.001
# multiIntersectBed -header -i Broad_CD14_RO01746_k4me3_1_1_ENCFF000CDX_hg19_0.001_peaks.bed Broad_CD14_RO01746_k4me3_2_1_ENCFF000CDZ_hg19_0.001_peaks.bed  UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_0.001_peaks.bed > k4me3.csv
#
# # 0.01
# multiIntersectBed -header -i Broad_CD14_RO01746_k4me3_1_1_ENCFF000CDX_hg19_0.01_peaks.bed Broad_CD14_RO01746_k4me3_2_1_ENCFF000CDZ_hg19_0.01_peaks.bed UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_0.01_peaks.bed > k4me3.csv
#
# # 0.1
# multiIntersectBed -header -i Broad_CD14_RO01746_k4me3_1_1_ENCFF000CDX_hg19_0.1_peaks.bed  Broad_CD14_RO01746_k4me3_2_1_ENCFF000CDZ_hg19_0.1_peaks.bed UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_0.1_peaks.bed > k4me3.csv
#
# ```

# %%
# Broad vs UW
processvenn3('/mnt/washu/oshpynov/encode_bams_macs_0.001/k4me3.csv')
processvenn3('/mnt/washu/oshpynov/encode_bams_macs_0.01/k4me3.csv')
processvenn3('/mnt/washu/oshpynov/encode_bams_macs_0.1/k4me3.csv')

# Broad peaks
processvenn3('/mnt/washu/oshpynov/encode_bams_macs_broad_0.001/k4me3_broad.csv')
processvenn3('/mnt/washu/oshpynov/encode_bams_macs_broad_0.01/k4me3_broad.csv')
processvenn3('/mnt/washu/oshpynov/encode_bams_macs_broad_0.1/k4me3_broad.csv')

# %% [markdown]
# # METAPEAKS ENCODE data
# ```
# # Metapeaks among Broad datasets
# # bash ~/work/washu/metapeaks.sh Broad*.bed
#
# # Metapeaks among Broad biological replicates and UW
# cd encode_bams_macs_0.1
# bash ~/work/washu/metapeaks.sh Broad_CD14_RO01746_k4me3_*_1*.bed UW_*_peaks.bed
# cd ../encode_bams_macs_0.01
# bash ~/work/washu/metapeaks.sh Broad_CD14_RO01746_k4me3_*_1*.bed UW_*_peaks.bed
# cd ../encode_bams_macs_0.001
# bash ~/work/washu/metapeaks.sh Broad_CD14_RO01746_k4me3_*_1*.bed UW_*_peaks.bed
# ```
# Output:
# ```
# CHRFILES: Broad_CD14_RO01746_k4me3_1_1_ENCFF000CDX_hg19_0.1_peaks.bed.chr_only.tmp Broad_CD14_RO01746_k4me3_2_1_ENCFF000CDZ_hg19_0.1_peaks.bed.chr_only.tmp UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_0.1_peaks.bed.chr_only.tmp
# PEAKS:    56383    51491    34910
# 0	0	1	1042
# 0	1	0	6101
# 0	1	1	298
# 1	0	0	10695
# 1	0	1	1122
# 1	1	0	13117
# 1	1	1	29255
#
# CHRFILES: Broad_CD14_RO01746_k4me3_1_1_ENCFF000CDX_hg19_0.01_peaks.bed.chr_only.tmp Broad_CD14_RO01746_k4me3_2_1_ENCFF000CDZ_hg19_0.01_peaks.bed.chr_only.tmp UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_0.01_peaks.bed.chr_only.tmp
# PEAKS:    45486    39688    32608
# 0	0	1	1332
# 0	1	0	2985
# 0	1	1	245
# 1	0	0	8035
# 1	0	1	1478
# 1	1	0	7621
# 1	1	1	26854
# CHRFILES: Broad_CD14_RO01746_k4me3_1_1_ENCFF000CDX_hg19_0.001_peaks.bed.chr_only.tmp Broad_CD14_RO01746_k4me3_2_1_ENCFF000CDZ_hg19_0.001_peaks.bed.chr_only.tmp UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_0.001_peaks.bed.chr_only.tmp
# PEAKS:    36847    34276    30816
# It looks as though you have less than 3 columns at line: 36847.  Are you sure your files are tab-delimited?
# 0	0	1	1317
# 0	1	0	1780
# 0	1	1	219
# 1	0	0	6435
# 1	0	1	1523
# 1	1	0	4971
# 1	1	1	22868
# ```

# %%
# %matplotlib inline
import pandas as pd
from matplotlib_venn import venn3
import matplotlib.pyplot as plt

def showvenn3(s1, s2, s3, abC, aBc, aBC, Abc, AbC, ABc, ABC):
    fig = plt.figure(figsize=(4, 4))
    venn3(subsets = (Abc, aBc, ABc, abC, AbC, aBC, ABC), set_labels = (s1, s2, s3))
    plt.show()
    
# Q=0.1
showvenn3('Broad1_1', 'Broad2_1', 'UW1_1', 1042, 6101, 298, 10695, 1122, 13117, 29255)
# Q=0.01
showvenn3('Broad1_1', 'Broad2_1', 'UW1_1', 1332, 2985, 245, 8035, 1478, 7621, 26854)
# Q=0.001
showvenn3('Broad1_1', 'Broad2_1', 'UW1_1', 1317, 1780, 219, 6435, 1523, 4971, 22868)

# %% [markdown]
# # METAPEAKS run6_run7
# ```
# cd run_6_run_7_trim_bams_macs_0.1
# bash ~/work/washu/metapeaks.sh *k4me3*.bed
# cd ../run_6_run_7_trim_bams_macs_0.01
# bash ~/work/washu/metapeaks.sh *k4me3*.bed
# cd ../run_6_run_7_trim_bams_macs_0.001
# bash ~/work/washu/metapeaks.sh *k4me3*.bed
# ```
# Output:
# ```
# CHRFILES: donor6_k4me3_5_hg19_0.1_peaks.bed.chr_only.tmp donor7_k4me3_5_hg19_0.1_peaks.bed.chr_only.tmp donor8_k4me3_5_hg19_0.1_peaks.bed.chr_only.tmp
# PEAKS:    61120    40715    83575
# 0	0	1	31218
# 0	1	0	7335
# 0	1	1	5806
# 1	0	0	11152
# 1	0	1	10893
# 1	1	0	1363
# 1	1	1	21494
# CHRFILES: donor6_k4me3_5_hg19_0.01_peaks.bed.chr_only.tmp donor7_k4me3_5_hg19_0.01_peaks.bed.chr_only.tmp donor8_k4me3_5_hg19_0.01_peaks.bed.chr_only.tmp
# PEAKS:    34991    24093    49681
# 0	0	1	17971
# 0	1	0	4258
# 0	1	1	4678
# 1	0	0	6915
# 1	0	1	8055
# 1	1	0	1179
# 1	1	1	12089
# CHRFILES: donor6_k4me3_5_hg19_0.001_peaks.bed.chr_only.tmp donor7_k4me3_5_hg19_0.001_peaks.bed.chr_only.tmp donor8_k4me3_5_hg19_0.001_peaks.bed.chr_only.tmp
# PEAKS:    19301    15588    36253
# 0	0	1	16796
# 0	1	0	3498
# 0	1	1	4159
# 1	0	0	4036
# 1	0	1	5289
# 1	1	0	636
# 1	1	1	6355
# ```

# %%
# Q=0.1
showvenn3('donor6', 'donor7', 'donor8', 31218, 7335, 5806, 11152, 10893, 1363, 21494)
# Q=0.01
showvenn3('donor6', 'donor7', 'donor8', 17971, 4258, 4678, 6915, 8055, 1179, 12089)
# Q=0.001
showvenn3('donor6', 'donor7', 'donor8', 16796, 3498, 4159, 4036, 5289, 636, 6355)

# %% [markdown]
# # METAPEAKS WIDE peaks run6_run7
# ```
# cd run_6_run_7_trim_bams_macs_broad_0.1
# bash ~/work/washu/metapeaks.sh *k4me3*.broadPeak
# cd ../run_6_run_7_trim_bams_macs_broad_0.01
# bash ~/work/washu/metapeaks.sh *k4me3*.broadPeak
# cd ../run_6_run_7_trim_bams_macs_broad_0.001
# bash ~/work/washu/metapeaks.sh *k4me3*.broadPeak
# ```
# Output:
# ```
# CHRFILES: donor6_k4me3_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp donor7_k4me3_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp donor8_k4me3_5_hg19_broad_0.1_peaks.broadPeak.chr_only.tmp
# PEAKS:    41279    34787    57587
# 0	0	1	25606
# 0	1	0	9832
# 0	1	1	3569
# 1	0	0	9298
# 1	0	1	4871
# 1	1	0	814
# 1	1	1	19480
# CHRFILES: donor6_k4me3_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp donor7_k4me3_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp donor8_k4me3_5_hg19_broad_0.01_peaks.broadPeak.chr_only.tmp
# PEAKS:    26957    19368    30457
# 0	0	1	7739
# 0	1	0	2095
# 0	1	1	1463
# 1	0	0	3452
# 1	0	1	3512
# 1	1	0	344
# 1	1	1	14792
# CHRFILES: donor6_k4me3_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp donor7_k4me3_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp donor8_k4me3_5_hg19_broad_0.001_peaks.broadPeak.chr_only.tmp
# PEAKS:    20224    14869    25280
# 0	0	1	6410
# 0	1	0	1162
# 0	1	1	1800
# 1	0	0	1846
# 1	0	1	3632
# 1	1	0	206
# 1	1	1	11243
# ```

# %%
# Q=0.001
showvenn3('donor6_wide', 'donor7_wide', 'donor8_wide', 6410, 1162, 1800, 1846, 3632, 206, 11243)
# Q=0.01
showvenn3('donor6_wide', 'donor7_wide', 'donor8_wide', 7739, 2095, 1463, 3452, 3512, 344, 14792)
# Q=0.1
showvenn3('donor6_wide', 'donor7_wide', 'donor8_wide', 25606, 9832, 3569, 9298, 4871, 814, 19480)

# %% [markdown]
# # Roadmap vs run_6_7 Q=0.01 Wide peaks
# Experiment:
# * Fix Q=0.001 for encode data. merge peaks for encode wide peaks
# * merge run 6, 7 k4me3 wide peaks for different Q values.
# * As result we see that overlap proportion increases with Q value decrease.
#
# ```
# mkdir encode_run67
# cd encode_run67
#
# # Merge run_6 run_7
# cd ../run_6_run_7_trim_bams_macs_broad_0.1
# bedtools merge -i donor6_k4me3_5_hg19_broad_0.1_peaks.broadPeak -i donor7_k4me3_5_hg19_broad_0.1_peaks.broadPeak -i donor8_k4me3_5_hg19_broad_0.1_peaks.broadPeak > merge_k4me3.bed
#
# cd ../run_6_run_7_trim_bams_macs_broad_0.01
# bedtools merge -i donor6_k4me3_5_hg19_broad_0.01_peaks.broadPeak -i donor7_k4me3_5_hg19_broad_0.01_peaks.broadPeak -i donor8_k4me3_5_hg19_broad_0.01_peaks.broadPeak > merge_k4me3.bed
#
# cd ../run_6_run_7_trim_bams_macs_broad_0.001
# bedtools merge -i donor6_k4me3_5_hg19_broad_0.001_peaks.broadPeak -i donor7_k4me3_5_hg19_broad_0.001_peaks.broadPeak -i donor8_k4me3_5_hg19_broad_0.001_peaks.broadPeak > merge_k4me3.bed
#
# # Merge encode
# cd ../encode_bams_macs_broad_0.001/
# bedtools merge -i Broad_CD14_RO01746_k4me3_1_1_ENCFF000CDX_hg19_broad_0.001_peaks.broadPeak -i Broad_CD14_RO01746_k4me3_2_1_ENCFF000CDZ_hg19_broad_0.001_peaks.broadPeak -i UW_CD14_RO01746_k4me3_1_1_ENCFF001FYS_hg19_broad_0.001_peaks.broadPeak > merge_k4me3.bed
#
# # Metapeaks overlap
# cd ../encode_run67
# bash ~/work/washu/metapeaks.sh ../run_6_run_7_trim_bams_macs_broad_0.1/merge_k4me3.bed ../encode_bams_macs_broad_0.001/merge_k4me3.bed > overlap_0.1.txt
#
# bash ~/work/washu/metapeaks.sh ../run_6_run_7_trim_bams_macs_broad_0.01/merge_k4me3.bed ../encode_bams_macs_broad_0.001/merge_k4me3.bed > overlap_0.01.txt
#
# bash ~/work/washu/metapeaks.sh ../run_6_run_7_trim_bams_macs_broad_0.001/merge_k4me3.bed ../encode_bams_macs_broad_0.001/merge_k4me3.bed > overlap_0.001.txt
#
# ```
#
# Output:
# ```
# # cat overlap_0.1.txt
# CHRFILES: ../run_6_run_7_trim_bams_macs_broad_0.1/merge_k4me3.bed.chr_only.tmp ../encode_bams_macs_broad_0.001/merge_k4me3.bed.chr_only.tmp
# PEAKS:    41279    34756
# 0	1	16734
# 1	0	22398
# 1	1	17842
#
# # cat overlap_0.01.txt
# CHRFILES: ../run_6_run_7_trim_bams_macs_broad_0.01/merge_k4me3.bed.chr_only.tmp ../encode_bams_macs_broad_0.001/merge_k4me3.bed.chr_only.tmp
# PEAKS:    26957    34756
# 0	1	19621
# 1	0	10782
# 1	1	15052
#
# # cat overlap_0.001.txt
# CHRFILES: ../run_6_run_7_trim_bams_macs_broad_0.001/merge_k4me3.bed.chr_only.tmp ../encode_bams_macs_broad_0.001/merge_k4me3.bed.chr_only.tmp
# PEAKS:    20224    34756
# 0	1	22093
# 1	0	6606
# 1	1	12622
# ```

# %%
# Q=0.1    
showvenn2('run67', 'encode', 16734, 22398, 17842)
# Q=0.01    
showvenn2('run67', 'encode', 19621, 10782, 15052)
# Q=0.001
showvenn2('run67', 'encode', 22093, 6606, 12622)
